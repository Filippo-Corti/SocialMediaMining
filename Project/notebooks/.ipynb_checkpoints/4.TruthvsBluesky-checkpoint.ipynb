# %%
from collections import Counter, deque, defaultdict
import random
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt
import importlib
import seaborn as sns
import matplotlib.cm as cm
import matplotlib.colors as colors
import community as community_louvain


from Project.utils.storage import truth_db as t_db
from Project.utils.storage import bluesky_db as b_db

importlib.reload(t_db)
importlib.reload(b_db)

truth_db = t_db.SQLiteTruthSaver(db_name='../db/truthsocial.db')
bluesky_db = b_db.SQLiteBlueSkySaver(db_name='../db/bluesky.db')

# %% [markdown]
# ## 0. Extracting Graphs and Subgraphs

# %%
# Truth_Graph = truth_db.extract_network()
# nx.write_gexf(Truth_Graph, "truth.gexf")
#
# Bluesky_Graph = bluesky_db.extract_network()
# nx.write_gexf(Bluesky_Graph, "bluesky.gexf")
#
# Truth_TopGraph = SQLiteTruthSaver().extract_network(top_k=1000)
# nx.write_gexf(Truth_TopGraph, "truth_top1000.gexf")
#
# Bluesky_TopGraph = SQLiteBlueSkySaver().extract_network(top_k=1000)
# nx.write_gexf(Bluesky_TopGraph, "bluesky_top1000.gexf")
#
# Truth_Graph = nx.read_gexf("truth.gexf")
# Bluesky_Graph = nx.read_gexf("bluesky.gexf")
# Truth_TopGraph = nx.read_gexf("truth_top1000.gexf")
# Bluesky_TopGraph = nx.read_gexf("bluesky_top1000.gexf")

Bluesky_G = nx.read_gexf("../graphs/bluesky.gexf")
Truth_G = nx.read_gexf("../graphs/truth_sub.gexf")

# %% [markdown]
# ## 1. Basic Measures
#
# Order, Size, Degree Distribution and Connected Components

# %%
def gini_coeff(x):
    x = np.sort(np.array(x))
    n = len(x)
    cumx = np.cumsum(x)
    return (n + 1 - 2 * np.sum(cumx) / cumx[-1]) / n

def analyze_graph(G, color):
    print(f"{G.order()} Nodes and {G.size()} Edges")
    print(f"Density is {nx.density(G)}")

    degree = dict(G.degree())
    in_degree = dict(G.in_degree())
    out_degree = dict(G.out_degree())
    degree_values = list(degree.values())
    in_degree_values = list(in_degree.values())
    out_degree_values = list(out_degree.values())

    # Calculate Lorenz Curve for the Distribution of Posts between Users
    posts_count_dict = np.sort([
        node['posts_count']
        for node_id, node in G.nodes(data=True)
    ])
    posts_count_cdf = np.cumsum(posts_count_dict) / sum(posts_count_dict)
    lam = nx.density(G) * (G.order() - 1)
    poisson_posts_count = np.sort(np.random.poisson(lam=lam, size=len(posts_count_dict)))
    poisson_posts_count_cdf = np.cumsum(poisson_posts_count) / sum(poisson_posts_count)


    count, bins = np.histogram(
        in_degree_values,
        bins=np.arange(0, max(in_degree_values) + 2)
    )
    pdf = count / G.order()
    ccdf = 1.0 - np.cumsum(pdf)

    ccdf[-1] = 0.0 # Fixes floating point error

    print(f"Nodes with in degree zero: {len([x for x in in_degree_values if x == 0])}")

    # Compute connected component sizes
    cc = list(nx.weakly_connected_components(G))
    component_sizes = sorted([len(c) for c in cc], reverse=True)
    components_by_size = Counter(component_sizes)

    # Print stats
    print(f"Min Degree: {min(degree_values)}")
    print(f"Max Degree: {max(degree_values)}")
    print(f"Average Degree: {np.mean(degree_values):.2f}")
    print(f"Average In-Degree: {np.mean(in_degree_values):.2f}")
    print(f"Average Out-Degree: {np.mean(out_degree_values):.2f}")

    print(f"There are {len(cc)} Connected Components:")
    for component in cc[:min(3, len(cc))]:
        print(f"\tConnected Component of size: {len(component)} ({len(component)/G.order():.2%})")
    print("\t...")

    top_in = sorted(in_degree.items(), key=lambda x: x[1], reverse=True)[:3]
    print("Top 3 Nodes by In-Degree:")
    for node, deg in top_in:
        attrs = G.nodes(data=True)[node]
        print(f"\tNode {attrs['username']} {attrs['url']}: In-Degree = {deg}")

    top_out = sorted(out_degree.items(), key=lambda x: x[1], reverse=True)[:3]
    print("Top 3 Nodes by Out-Degree:")
    for node, deg in top_out:
        attrs = G.nodes(data=True)[node]
        print(f"\tNode {attrs['username']} {attrs['url']}: Out-Degree = {deg}")

    # Degree Centrality
    deg_centrality = nx.degree_centrality(G)
    top_deg_centrality = sorted(deg_centrality.items(), key=lambda x: x[1], reverse=True)[:3]
    print("Top 3 Nodes by Degree Centrality:")
    for node, centrality in top_deg_centrality:
        attrs = G.nodes(data=True)[node]
        print(f"\tNode {attrs['username']} {attrs['url']}: Degree Centrality = {centrality:.4f}")


    plt.figure(figsize=(7, 4))
    plt.plot(bins[:-1], pdf, marker='o', linestyle='--', label="Degree PDF", color=color)
    #plt.xscale("log")
    #plt.yscale("log")
    plt.title("In-Degree PDF")
    plt.xlabel("Degree")
    plt.ylabel("PDF - P(X=x)")
    plt.grid()
    plt.show()

    plt.figure(figsize=(7, 4))
    plt.plot(bins[:-1], ccdf, marker='o', linestyle='--', label="Degree CCDF", color=color)
    plt.xscale("log")
    plt.yscale("log")
    plt.title("In-Degree CCDF")
    plt.xlabel("Degree")
    plt.ylabel("CCDF - P(X>x)")
    plt.grid()
    plt.show()

    plt.figure(figsize=(7, 4))
    plt.scatter(np.arange(len(posts_count_cdf)) / (len(posts_count_dict) - 1), posts_count_cdf, marker='o', linestyle='--', label="Network", color=color)
    plt.scatter(np.arange(len(poisson_posts_count_cdf)) / (len(poisson_posts_count) - 1), poisson_posts_count_cdf, marker='o', linestyle='--', label="Erdos-Renyi Random Network", color="gray")
    plt.plot([0, 1], [0, 1], 'k--', label="Equality Line")
    plt.title("Lorenz Curve of Posts per User")
    plt.xlabel("Cum. % of Users")
    plt.ylabel("Cum. % of Posts")
    plt.legend()
    plt.grid()
    plt.show()

    print(f"Gini Coefficient: {gini_coeff(posts_count_dict):.5f}")

    plt.figure(figsize=(7, 4))
    plt.scatter(list(components_by_size.keys()), list(components_by_size.values()), color=color)
    plt.xscale("log")
    plt.yscale("log")
    plt.title("Weakly Connected Components")
    plt.xlabel("Component Size")
    plt.ylabel("# of Components")
    plt.grid()
    plt.show()

    plt.figure(figsize=(7, 4))
    plt.hist(list(deg_centrality.values()), bins=50, log=True, color=color, alpha=0.7)
    plt.title("Distribuzione Degree Centrality")
    plt.xlabel("Degree Centrality")
    plt.ylabel("Frequency")
    plt.grid()
    plt.show()

# %%
#analyze_graph(Truth_Graph, color='red')

# %%
#analyze_graph(Bluesky_Graph, color='blue')

# %%
#analyze_graph(Truth_TopGraph, color='coral')

# %%
#analyze_graph(Bluesky_TopGraph, color='royalblue')

# %%
def bidirectional_forest_fire_sample(G, max_nodes, seed_node=None, p_forward=0.7):
    """Compared to traditional Forest Fire Sampling, the neighbors selected for burning can either be at the end of out-links or in-links"""
    if seed_node is None:
        seed_node = random.choice(list(G.nodes))

    sampled_nodes = {seed_node}
    queue = [seed_node]

    while queue and len(sampled_nodes) < max_nodes:
        current = queue.pop(0)

        # Combine outgoing and incoming edges
        try:
            neighbors = set(G.successors(current)) | set(G.predecessors(current))
        except:
            neighbors = set(G.neighbors(current))  # Fallback for undirected

        neighbors -= sampled_nodes
        if not neighbors:
            continue

        # Burn a random number of neighbors (at least 1 if possible)
        burn_count = max(1, int(len(neighbors) * p_forward))
        burn_count = min(burn_count, len(neighbors))  # Avoid overflow

        neighbors = list(neighbors)
        random.shuffle(neighbors)
        for neighbor in neighbors[:burn_count]:
            if neighbor not in sampled_nodes:
                sampled_nodes.add(neighbor)
                queue.append(neighbor)
                if len(sampled_nodes) >= max_nodes:
                    break

    return G.subgraph(sampled_nodes).copy()

# %%
#Truth_Subgraph = bidirectional_forest_fire_sample(Truth_Graph, max_nodes=len(Bluesky_Graph.nodes()))

# %%
#analyze_graph(Truth_Subgraph, color='coral')

# %%
#nx.write_gexf(Truth_Subgraph, "truth_sub.gexf")

# %%
# So the graphs are:

# bluesky.gexf (14k nodes, 17k edges)
# truth_sub.gexf (14k nodes, 29k edges) - obtained with forest fire sampling

# Now Echo Chambers via:
# - Stance Assortativity (facile)
# - Neighbourhood Leaning (medio)
# - Community Homophily (medio)
# - Information Difussion Simulation (SIR) (difficile)

# Per poterlo fare, prima conviene calcolare la stance e metterla come attributo dei nodi

# %%
Truth_G.order(), Truth_G.size()
# Out:
# (14748, 30556)

# %%
Bluesky_G.order(), Bluesky_G.size()
# Out:
# (14748, 17623)

# %%
analyze_graph(Truth_G, color='red')
# Out:
# 14748 Nodes and 30556 Edges
# Density is 0.00014049461940919834
# Nodes with in degree zero: 10959
# Min Degree: 1
# Max Degree: 10119
# Average Degree: 4.14
# Average In-Degree: 2.07
# Average Out-Degree: 2.07
# There are 1 Connected Components:
# 	Connected Component of size: 14748 (100.00%)
# 	...
# Top 3 Nodes by In-Degree:
# 	Node realDonaldTrump https://truthsocial.com/@realDonaldTrump: In-Degree = 10119
# 	Node joemccuiston https://truthsocial.com/@joemccuiston: In-Degree = 1100
# 	Node OAN https://truthsocial.com/@OAN: In-Degree = 1062
# Top 3 Nodes by Out-Degree:
# 	Node DaKine17 https://truthsocial.com/@DaKine17: Out-Degree = 539
# 	Node char_smi3 https://truthsocial.com/@char_smi3: Out-Degree = 98
# 	Node Yatti420 https://truthsocial.com/@Yatti420: Out-Degree = 54
# Top 3 Nodes by Degree Centrality:
# 	Node realDonaldTrump https://truthsocial.com/@realDonaldTrump: Degree Centrality = 0.6862
# 	Node joemccuiston https://truthsocial.com/@joemccuiston: Degree Centrality = 0.0749
# 	Node OAN https://truthsocial.com/@OAN: Degree Centrality = 0.0720
# Gini Coefficient: 0.57612

# %%
analyze_graph(Bluesky_G, color='royalblue')
# Out:
# 14748 Nodes and 17623 Edges
# Density is 8.10294763008346e-05
# Nodes with in degree zero: 13953
# Min Degree: 1
# Max Degree: 1149
# Average Degree: 2.39
# Average In-Degree: 1.19
# Average Out-Degree: 1.19
# There are 246 Connected Components:
# 	Connected Component of size: 13960 (94.66%)
# 	Connected Component of size: 8 (0.05%)
# 	Connected Component of size: 7 (0.05%)
# 	...
# Top 3 Nodes by In-Degree:
# 	Node atrupar.com https://bsky.app/profile/atrupar.com: In-Degree = 1149
# 	Node mollyjongfast.bsky.social https://bsky.app/profile/mollyjongfast.bsky.social: In-Degree = 817
# 	Node artcandee.bsky.social https://bsky.app/profile/artcandee.bsky.social: In-Degree = 778
# Top 3 Nodes by Out-Degree:
# 	Node mccarthypm.bsky.social https://bsky.app/profile/mccarthypm.bsky.social: Out-Degree = 22
# 	Node robertomitchelli.bsky.social https://bsky.app/profile/robertomitchelli.bsky.social: Out-Degree = 17
# 	Node nameless62.bsky.social https://bsky.app/profile/nameless62.bsky.social: Out-Degree = 17
# Top 3 Nodes by Degree Centrality:
# 	Node atrupar.com https://bsky.app/profile/atrupar.com: Degree Centrality = 0.0779
# 	Node mollyjongfast.bsky.social https://bsky.app/profile/mollyjongfast.bsky.social: Degree Centrality = 0.0555
# 	Node artcandee.bsky.social https://bsky.app/profile/artcandee.bsky.social: Degree Centrality = 0.0528
# Gini Coefficient: 0.22139

# %%
truth_nodes = {
    node: attrs
    for node, attrs in Truth_G.nodes(data=True)
    if attrs['average_stance'] not in [0, 1, -1] # These values usually mean not enough data
}

truth_stances = [
    attrs['average_stance'] for node, attrs in truth_nodes.items()
]

# Set the plot style
sns.set(style='whitegrid')

# Create histogram + KDE
sns.histplot(truth_stances, bins=20, kde=True, color='skyblue', edgecolor='black')

# Add labels and limits
plt.title('Distribution of User Stances (Truth)')
plt.xlabel('Coefficient Value')
plt.ylabel('Frequency')
plt.xlim(-1, 1)

plt.show()

# %%
bluesky_nodes = {
    node: attrs
    for node, attrs in Bluesky_G.nodes(data=True)
    if attrs['average_stance'] not in [0, 1, -1] # These values usually mean not enough data
}

bluesky_stances = [
    attrs['average_stance'] for _, attrs in bluesky_nodes.items()
]

# Set the plot style
sns.set(style='whitegrid')

# Create histogram + KDE
sns.histplot(bluesky_stances, bins=20, kde=True, color='skyblue', edgecolor='black')

# Add labels and limits
plt.title('Distribution of User Stances (Bluesky)')
plt.xlabel('Coefficient Value')
plt.ylabel('Frequency')
plt.xlim(-1, 1)

plt.show()

# %%
# Assortativities

truth_assort = nx.numeric_assortativity_coefficient(Truth_G, attribute='average_stance') # Very weak
bluesky_assort = nx.numeric_assortativity_coefficient(Bluesky_G, attribute='average_stance') # Very weak

print(truth_assort, bluesky_assort)
# Out:
# 0.07914508300361561 0.07548975804329566

# %%
import random
import numpy as np

def randomized_assortativity(G, attribute, n_trials=1000):
    stances = [G.nodes[n][attribute] for n in G.nodes]
    assortativities = []

    for _ in range(n_trials):
        shuffled_stances = random.sample(stances, len(stances))
        # Temporarily assign shuffled stances
        for node, new_stance in zip(G.nodes, shuffled_stances):
            G.nodes[node]['_shuffled'] = new_stance
        coeff = nx.numeric_assortativity_coefficient(G, '_shuffled')
        assortativities.append(coeff)

    return np.array(assortativities)

null_distribution = randomized_assortativity(Truth_G, 'average_stance', n_trials=1000)

# %%
plt.hist(null_distribution, bins=30, alpha=0.7, label='Null distribution')
plt.axvline(truth_assort, color='red', linestyle='dashed', label='Observed assortativity')
plt.xlabel('Assortativity Coefficient')
plt.ylabel('Frequency')
plt.legend()
plt.title('Assortativity Significance Test')
plt.show()

# %%
null_distribution = randomized_assortativity(Bluesky_G, 'average_stance', n_trials=1000)

# %%
plt.hist(null_distribution, bins=30, alpha=0.7, label='Null distribution')
plt.axvline(truth_assort, color='red', linestyle='dashed', label='Observed assortativity')
plt.xlabel('Assortativity Coefficient')
plt.ylabel('Frequency')
plt.legend()
plt.title('Assortativity Significance Test')
plt.show()

# %%
# Neighbourhood Leaning

def neighbour_stance(G, n):
    return np.average([
        G.nodes(data=True)[neighbour_id]['average_stance']
        for neighbour_id in nx.all_neighbors(G, n)
    ])

neighbour_truth_stances = [
    float(neighbour_stance(Truth_G, n)) for n, _ in truth_nodes.items()
]

g = sns.jointplot(
    x=truth_stances,
    y=neighbour_truth_stances,
    kind="kde",
    fill=True,
    cmap="magma",
    bw_adjust=0.9,
    thresh=0.01,
    levels=100,
    marginal_kws=dict(fill=True),
)

g.ax_joint.grid(False)
g.ax_joint.set_facecolor("black")
g.ax_joint.set_xlabel("Individual Leaning")
g.ax_joint.set_ylabel("Neighbourhood Leaning")

g.fig.suptitle("Joint Distribution of Leaning and Neighbour Leaning (Truth)", y=1.02)
plt.show()

# %%
# Neighbourhood Leaning

neighbour_bluesky_stances = [
    float(neighbour_stance(Bluesky_G, n)) for n, _ in bluesky_nodes.items()
]

g = sns.jointplot(
    x=bluesky_stances,
    y=neighbour_bluesky_stances,
    kind="kde",
    fill=True,
    cmap="magma",
    bw_adjust=0.9,
    thresh=0.01,
    levels=100,
    marginal_kws=dict(fill=True),
)

g.ax_joint.grid(False)
g.ax_joint.set_facecolor("black")
g.ax_joint.set_xlabel("Individual Leaning")
g.ax_joint.set_ylabel("Neighbourhood Leaning")

g.fig.suptitle("Joint Distribution of Leaning and Neighbour Leaning (BlueSky)", y=1.02)
plt.show()

# %%
def print_communities_stance_histogram(
        sizes,
        stances
):
    ids = list(sizes.keys())
    y = [sizes[id] for id in ids]
    stance_values = np.array([stances[id] for id in ids])

    norm = colors.Normalize(vmin=-1, vmax=1)

    # Define the boundaries of your bins (edges of intervals)
    bounds = [-1.0, -0.75, -0.5, -0.25, 0, 0.25, 0.5, 0.75, 1.0]

    # Define the discrete colors for each bin (8 bins -> 8 colors)
    colors_list = [
        '#0000cc',  # dark blue (x = -1 to -0.75)
        '#3366ff',  # medium blue
        '#99ccff',  # light blue
        '#cce6ff',  # very light blue
        '#ffe6e6',  # very light red / pinkish
        '#ff9999',  # light red
        '#ff4d4d',  # medium red
        '#cc0000'   # dark red (x = 0.75 to 1)
    ]

    # Create colormap and norm
    cmap = colors.ListedColormap(colors_list)
    norm = colors.BoundaryNorm(bounds, cmap.N)

    bar_colors = cmap(norm(stance_values))

    fig, ax = plt.subplots(figsize=(8,5))
    bars = ax.bar(ids, y, color=bar_colors)

    ax.set_xlabel('ID')
    ax.set_ylabel('Size')
    ax.set_title('Sizes colored by Stance (Red to Blue)')

    # Pass ax to colorbar to avoid ValueError
    sm = cm.ScalarMappable(cmap=cmap, norm=norm)
    sm.set_array([])  # Needed for colorbar

    cbar = plt.colorbar(sm, ax=ax)
    cbar.set_label('Stance (-1 to 1)')

    plt.show()

# %%
# Community Homophily

partition_truth = community_louvain.best_partition(
    Truth_G.to_undirected(),
    resolution=1.0
)

community_ids_truth = set(partition_truth.values())

communities_truth = {
    community_id: {
        node: Truth_G.nodes(data=True)[node] for node, comm in partition_truth.items()
        if comm == community_id
    }
    for community_id in community_ids_truth
}

communities_truth = {
    community_id: nodes
    for community_id, nodes in communities_truth.items()
    if len(nodes) > 50
}

communities_truth_sizes = {
    community_id: len(nodes)
    for community_id, nodes in communities_truth.items()
}

print(f"Communities: {len(communities_truth)}")

communities_leanings_truth = {
    community_id: np.average(
        a=[n['average_stance'] for _, n in nodes.items()],
        weights=[n['posts_count'] for _, n in nodes.items()]
    )
    for community_id, nodes in communities_truth.items()
}

print_communities_stance_histogram(
    communities_truth_sizes,
    communities_leanings_truth
)
# Out:
# Communities: 15

# %%
# What are those blue communities ????

comm_6 = communities_truth[6]

comm_6 # Ci ha preso veramente:

# Guardare:
# https://truthsocial.com/@NJC802
# https://truthsocial.com/@Faketriots
# https://truthsocial.com/@Lmao_at_trumps_spelling
# Out:
# {'108783594593870400': {'username': 'GNorberg',
#   'display_name': 'Ewegot',
#   'url': 'https://truthsocial.com/@GNorberg',
#   'posts_count': 13,
#   'average_stance': 0.23076923076923078,
#   'label': '108783594593870400'},
#  '107864384110055008': {'username': 'KennedyBohanon',
#   'display_name': 'OnTheBuckle MAGA🇺🇸BrutalAmerican',
#   'url': 'https://truthsocial.com/@KennedyBohanon',
#   'posts_count': 5,
#   'average_stance': 0.6,
#   'label': '107864384110055008'},
#  '107848556075017498': {'username': 'Dirty_Harry1960',
#   'display_name': 'Dirty Harry',
#   'url': 'https://truthsocial.com/@Dirty_Harry1960',
#   'posts_count': 41,
#   'average_stance': 0.2926829268292683,
#   'label': '107848556075017498'},
#  '107850933408960148': {'username': 'AllCountry',
#   'display_name': 'Born Free',
#   'url': 'https://truthsocial.com/@AllCountry',
#   'posts_count': 4,
#   'average_stance': 0.25,
#   'label': '107850933408960148'},
#  '108285605399716574': {'username': 'jameshilary',
#   'display_name': 'Armed',
#   'url': 'https://truthsocial.com/@jameshilary',
#   'posts_count': 3,
#   'average_stance': 0.3333333333333333,
#   'label': '108285605399716574'},
#  '107835795601445646': {'username': 'RobbyF',
#   'display_name': 'RobbyF',
#   'url': 'https://truthsocial.com/@RobbyF',
#   'posts_count': 5,
#   'average_stance': 0.2,
#   'label': '107835795601445646'},
#  '113420368619452696': {'username': 'Ladyfencer2000',
#   'display_name': 'Ladyfencer2000',
#   'url': 'https://truthsocial.com/@Ladyfencer2000',
#   'posts_count': 3,
#   'average_stance': -0.6666666666666666,
#   'label': '113420368619452696'},
#  '109389144388385803': {'username': 'Rina_1',
#   'display_name': 'Rina_1',
#   'url': 'https://truthsocial.com/@Rina_1',
#   'posts_count': 7,
#   'average_stance': 0.5714285714285714,
#   'label': '109389144388385803'},
#  '109521500041004420': {'username': 'Blooper01',
#   'display_name': 'Blooper01',
#   'url': 'https://truthsocial.com/@Blooper01',
#   'posts_count': 24,
#   'average_stance': 0.08333333333333333,
#   'label': '109521500041004420'},
#  '114071924283859889': {'username': 'real_truth_speaker',
#   'display_name': 'real_truth_speaker',
#   'url': 'https://truthsocial.com/@real_truth_speaker',
#   'posts_count': 4,
#   'average_stance': -1.0,
#   'label': '114071924283859889'},
#  '111452787126116822': {'username': 'Faketriots',
#   'display_name': 'Faketriots Watch',
#   'url': 'https://truthsocial.com/@Faketriots',
#   'posts_count': 5,
#   'average_stance': -0.4,
#   'label': '111452787126116822'},
#  '111535714545669324': {'username': 'DavidMG83',
#   'display_name': 'DavidMG83',
#   'url': 'https://truthsocial.com/@DavidMG83',
#   'posts_count': 5,
#   'average_stance': -0.2,
#   'label': '111535714545669324'},
#  '110077886900696203': {'username': 'Lmao_at_trumps_spelling',
#   'display_name': 'Reagan Republican',
#   'url': 'https://truthsocial.com/@Lmao_at_trumps_spelling',
#   'posts_count': 5,
#   'average_stance': -0.4,
#   'label': '110077886900696203'},
#  '112146009970177532': {'username': 'Larss247',
#   'display_name': 'Larss',
#   'url': 'https://truthsocial.com/@Larss247',
#   'posts_count': 4,
#   'average_stance': 0.0,
#   'label': '112146009970177532'},
#  '113022845092016300': {'username': 'NJC802',
#   'display_name': 'NJC802',
#   'url': 'https://truthsocial.com/@NJC802',
#   'posts_count': 6,
#   'average_stance': -0.5,
#   'label': '113022845092016300'},
#  '108210689375353562': {'username': 'dbarbour',
#   'display_name': 'DenoforTrump',
#   'url': 'https://truthsocial.com/@dbarbour',
#   'posts_count': 15,
#   'average_stance': 0.06666666666666667,
#   'label': '108210689375353562'},
#  '109638030075750263': {'username': 'BillieRoenne',
#   'display_name': 'Professor of Human & Machine Intel, PhD',
#   'url': 'https://truthsocial.com/@BillieRoenne',
#   'posts_count': 9,
#   'average_stance': 0.4444444444444444,
#   'label': '109638030075750263'},
#  '108202286218898661': {'username': 'marlinsman1',
#   'display_name': 'Weird Orange',
#   'url': 'https://truthsocial.com/@marlinsman1',
#   'posts_count': 41,
#   'average_stance': -0.21951219512195122,
#   'label': '108202286218898661'},
#  '108353590624210631': {'username': 'crazyinlife',
#   'display_name': 'crazyinlife',
#   'url': 'https://truthsocial.com/@crazyinlife',
#   'posts_count': 13,
#   'average_stance': -0.8461538461538461,
#   'label': '108353590624210631'},
#  '108836234431795676': {'username': 'frogzard',
#   'display_name': 'frogzard',
#   'url': 'https://truthsocial.com/@frogzard',
#   'posts_count': 8,
#   'average_stance': 0.25,
#   'label': '108836234431795676'},
#  '112260284312804740': {'username': 'DrjUSA',
#   'display_name': 'RELENTLESS',
#   'url': 'https://truthsocial.com/@DrjUSA',
#   'posts_count': 7,
#   'average_stance': 0.14285714285714285,
#   'label': '112260284312804740'},
#  '113349438314971640': {'username': 'Against2system',
#   'display_name': 'Against2system',
#   'url': 'https://truthsocial.com/@Against2system',
#   'posts_count': 3,
#   'average_stance': -0.3333333333333333,
#   'label': '113349438314971640'},
#  '108589912899569360': {'username': 'renomax',
#   'display_name': 'renomax',
#   'url': 'https://truthsocial.com/@renomax',
#   'posts_count': 3,
#   'average_stance': 0.0,
#   'label': '108589912899569360'},
#  '107838685390178934': {'username': 'bobinPa000000',
#   'display_name': 'bob the scientist',
#   'url': 'https://truthsocial.com/@bobinPa000000',
#   'posts_count': 5,
#   'average_stance': 0.2,
#   'label': '107838685390178934'},
#  '107835771036866101': {'username': 'CaringPatriot',
#   'display_name': '',
#   'url': 'https://truthsocial.com/@CaringPatriot',
#   'posts_count': 5,
#   'average_stance': 0.4,
#   'label': '107835771036866101'},
#  '108217741433221546': {'username': 'frankiehickman',
#   'display_name': 'Frankie',
#   'url': 'https://truthsocial.com/@frankiehickman',
#   'posts_count': 7,
#   'average_stance': 0.0,
#   'label': '108217741433221546'},
#  '113318506442003102': {'username': 'K_Freedom',
#   'display_name': 'K_Freedom',
#   'url': 'https://truthsocial.com/@K_Freedom',
#   'posts_count': 4,
#   'average_stance': 0.0,
#   'label': '113318506442003102'},
#  '107839284380571831': {'username': 'subcop42',
#   'display_name': '',
#   'url': 'https://truthsocial.com/@subcop42',
#   'posts_count': 3,
#   'average_stance': -0.3333333333333333,
#   'label': '107839284380571831'},
#  '108854310163611826': {'username': 'richardcpousn',
#   'display_name': 'Richard',
#   'url': 'https://truthsocial.com/@richardcpousn',
#   'posts_count': 1,
#   'average_stance': 0.0,
#   'label': '108854310163611826'},
#  '107926705406304781': {'username': 'mayface',
#   'display_name': 'mayface',
#   'url': 'https://truthsocial.com/@mayface',
#   'posts_count': 4,
#   'average_stance': 0.0,
#   'label': '107926705406304781'},
#  '112707368975368687': {'username': 'FLJohn68',
#   'display_name': 'FLJohn68',
#   'url': 'https://truthsocial.com/@FLJohn68',
#   'posts_count': 2,
#   'average_stance': 0.0,
#   'label': '112707368975368687'},
#  '110865995592291355': {'username': 'gamerguy1004',
#   'display_name': 'adam',
#   'url': 'https://truthsocial.com/@gamerguy1004',
#   'posts_count': 10,
#   'average_stance': -0.1,
#   'label': '110865995592291355'},
#  '107834596877787199': {'username': 'apostleofpossum',
#   'display_name': 'apostle of the possum',
#   'url': 'https://truthsocial.com/@apostleofpossum',
#   'posts_count': 1,
#   'average_stance': 0.0,
#   'label': '107834596877787199'},
#  '110833094800824865': {'username': 'Ealorenz',
#   'display_name': 'Betty',
#   'url': 'https://truthsocial.com/@Ealorenz',
#   'posts_count': 7,
#   'average_stance': 0.2857142857142857,
#   'label': '110833094800824865'},
#  '108320991743351840': {'username': 'ajdelval',
#   'display_name': 'ajdelval',
#   'url': 'https://truthsocial.com/@ajdelval',
#   'posts_count': 4,
#   'average_stance': 0.0,
#   'label': '108320991743351840'},
#  '112114053376559372': {'username': 'Space_Force_One',
#   'display_name': 'SPACE FORCE ONE 🇺🇸',
#   'url': 'https://truthsocial.com/@Space_Force_One',
#   'posts_count': 5,
#   'average_stance': 0.4,
#   'label': '112114053376559372'},
#  '110361468337259704': {'username': 'DDCOLT777',
#   'display_name': '',
#   'url': 'https://truthsocial.com/@DDCOLT777',
#   'posts_count': 4,
#   'average_stance': -0.25,
#   'label': '110361468337259704'},
#  '112270829669010295': {'username': 'spencer0204',
#   'display_name': 'SpencerT',
#   'url': 'https://truthsocial.com/@spencer0204',
#   'posts_count': 2,
#   'average_stance': 0.0,
#   'label': '112270829669010295'},
#  '108654355235886330': {'username': 'billsimpson9',
#   'display_name': 'bill',
#   'url': 'https://truthsocial.com/@billsimpson9',
#   'posts_count': 11,
#   'average_stance': -0.6363636363636364,
#   'label': '108654355235886330'},
#  '112287938509770683': {'username': 'Kasey078',
#   'display_name': 'Focus',
#   'url': 'https://truthsocial.com/@Kasey078',
#   'posts_count': 2,
#   'average_stance': 0.0,
#   'label': '112287938509770683'},
#  '107911169159726993': {'username': 'valentine72',
#   'display_name': 'Val',
#   'url': 'https://truthsocial.com/@valentine72',
#   'posts_count': 2,
#   'average_stance': 0.0,
#   'label': '107911169159726993'},
#  '108324060552523360': {'username': 'Crazy4Country',
#   'display_name': 'CindyLuWhoNotaPanican',
#   'url': 'https://truthsocial.com/@Crazy4Country',
#   'posts_count': 6,
#   'average_stance': -0.16666666666666666,
#   'label': '108324060552523360'},
#  '114241318083268289': {'username': 'Dirtycleats',
#   'display_name': 'Dirty Cleats and Sheets',
#   'url': 'https://truthsocial.com/@Dirtycleats',
#   'posts_count': 2,
#   'average_stance': -0.5,
#   'label': '114241318083268289'},
#  '107838078221801071': {'username': 'JClaypool',
#   'display_name': 'Iconoclastic Goat',
#   'url': 'https://truthsocial.com/@JClaypool',
#   'posts_count': 10,
#   'average_stance': 0.2,
#   'label': '107838078221801071'},
#  '107837318908756565': {'username': 'drknlvly30',
#   'display_name': 'Nunya',
#   'url': 'https://truthsocial.com/@drknlvly30',
#   'posts_count': 30,
#   'average_stance': 0.0,
#   'label': '107837318908756565'},
#  '107838050608863556': {'username': 'ckahler123',
#   'display_name': 'AntiTrump',
#   'url': 'https://truthsocial.com/@ckahler123',
#   'posts_count': 6,
#   'average_stance': -0.16666666666666666,
#   'label': '107838050608863556'},
#  '108755533396500220': {'username': 'sjs1953',
#   'display_name': 'sjs1953',
#   'url': 'https://truthsocial.com/@sjs1953',
#   'posts_count': 5,
#   'average_stance': -0.4,
#   'label': '108755533396500220'},
#  '114078370787554316': {'username': 'TwoShirtsMcGee',
#   'display_name': 'TwoShirtsMcGee',
#   'url': 'https://truthsocial.com/@TwoShirtsMcGee',
#   'posts_count': 5,
#   'average_stance': 0.0,
#   'label': '114078370787554316'},
#  '114215823689613326': {'username': 'Savebarabbas',
#   'display_name': 'Barabbas',
#   'url': 'https://truthsocial.com/@Savebarabbas',
#   'posts_count': 11,
#   'average_stance': 0.45454545454545453,
#   'label': '114215823689613326'},
#  '107855950588793470': {'username': 'bradscribner',
#   'display_name': 'B',
#   'url': 'https://truthsocial.com/@bradscribner',
#   'posts_count': 7,
#   'average_stance': 0.2857142857142857,
#   'label': '107855950588793470'},
#  '112203189722806144': {'username': 'V0ice0fReas0n',
#   'display_name': 'V0ice0fReas0n',
#   'url': 'https://truthsocial.com/@V0ice0fReas0n',
#   'posts_count': 5,
#   'average_stance': 0.4,
#   'label': '112203189722806144'},
#  '109172849007474949': {'username': 'Hi_friend',
#   'display_name': 'Hi_friend',
#   'url': 'https://truthsocial.com/@Hi_friend',
#   'posts_count': 17,
#   'average_stance': -0.35294117647058826,
#   'label': '109172849007474949'},
#  '107854720901292830': {'username': 'terrylehmann2',
#   'display_name': 'Terry Jean',
#   'url': 'https://truthsocial.com/@terrylehmann2',
#   'posts_count': 1,
#   'average_stance': 1.0,
#   'label': '107854720901292830'},
#  '109650285868356908': {'username': 'Lindlerof5',
#   'display_name': '',
#   'url': 'https://truthsocial.com/@Lindlerof5',
#   'posts_count': 2,
#   'average_stance': 0.5,
#   'label': '109650285868356908'},
#  '109031980983655251': {'username': 'Trumptruthfactcheck',
#   'display_name': 'Trumptruthfactcheck',
#   'url': 'https://truthsocial.com/@Trumptruthfactcheck',
#   'posts_count': 2,
#   'average_stance': -0.5,
#   'label': '109031980983655251'},
#  '107856882549417354': {'username': 'kuzamb',
#   'display_name': '',
#   'url': 'https://truthsocial.com/@kuzamb',
#   'posts_count': 4,
#   'average_stance': 0.5,
#   'label': '107856882549417354'},
#  '107898977197536220': {'username': 'TCarron63',
#   'display_name': 'TCarron',
#   'url': 'https://truthsocial.com/@TCarron63',
#   'posts_count': 3,
#   'average_stance': 0.3333333333333333,
#   'label': '107898977197536220'},
#  '110080123630372936': {'username': 'meagainnj',
#   'display_name': 'meagainnj',
#   'url': 'https://truthsocial.com/@meagainnj',
#   'posts_count': 7,
#   'average_stance': 0.0,
#   'label': '110080123630372936'},
#  '108339053165100319': {'username': 'savior7',
#   'display_name': 'savior7',
#   'url': 'https://truthsocial.com/@savior7',
#   'posts_count': 12,
#   'average_stance': -0.08333333333333333,
#   'label': '108339053165100319'},
#  '107859337350781055': {'username': 'bbsitter57',
#   'display_name': 'bbsitter57',
#   'url': 'https://truthsocial.com/@bbsitter57',
#   'posts_count': 4,
#   'average_stance': 0.5,
#   'label': '107859337350781055'},
#  '107888807934531562': {'username': 'marsmars11',
#   'display_name': 'Mars 🔴',
#   'url': 'https://truthsocial.com/@marsmars11',
#   'posts_count': 4,
#   'average_stance': 0.0,
#   'label': '107888807934531562'},
#  '107998328196584397': {'username': 'Matthew4Truth',
#   'display_name': '',
#   'url': 'https://truthsocial.com/@Matthew4Truth',
#   'posts_count': 2,
#   'average_stance': 0.5,
#   'label': '107998328196584397'},
#  '113935902009810227': {'username': 'cmellmer4',
#   'display_name': 'Cory',
#   'url': 'https://truthsocial.com/@cmellmer4',
#   'posts_count': 14,
#   'average_stance': 0.07142857142857142,
#   'label': '113935902009810227'},
#  '107843133788029471': {'username': 'dedenbigboy',
#   'display_name': 'Dedenbigboy.',
#   'url': 'https://truthsocial.com/@dedenbigboy',
#   'posts_count': 2,
#   'average_stance': 0.0,
#   'label': '107843133788029471'},
#  '107839905925699694': {'username': 'reverendB',
#   'display_name': 'Mz B',
#   'url': 'https://truthsocial.com/@reverendB',
#   'posts_count': 1,
#   'average_stance': 0.0,
#   'label': '107839905925699694'},
#  '114093896358908779': {'username': 'xtianrecords',
#   'display_name': '',
#   'url': 'https://truthsocial.com/@xtianrecords',
#   'posts_count': 3,
#   'average_stance': -0.3333333333333333,
#   'label': '114093896358908779'},
#  '108194469657155543': {'username': 'Danny787',
#   'display_name': '',
#   'url': 'https://truthsocial.com/@Danny787',
#   'posts_count': 2,
#   'average_stance': 0.5,
#   'label': '108194469657155543'},
#  '114105546763316817': {'username': 'Trumpisdumb20252025',
#   'display_name': 'Trumpisdumb20252025',
#   'url': 'https://truthsocial.com/@Trumpisdumb20252025',
#   'posts_count': 10,
#   'average_stance': -0.3,
#   'label': '114105546763316817'},
#  '107839125292333301': {'username': 'kinggair2',
#   'display_name': 'YUNI GAUDENTI',
#   'url': 'https://truthsocial.com/@kinggair2',
#   'posts_count': 2,
#   'average_stance': 0.5,
#   'label': '107839125292333301'},
#  '107841664416965881': {'username': 'k9house',
#   'display_name': 'LizCarol',
#   'url': 'https://truthsocial.com/@k9house',
#   'posts_count': 3,
#   'average_stance': 0.0,
#   'label': '107841664416965881'},
#  '113874359485581537': {'username': 'FelonPresident',
#   'display_name': 'FelonPresident',
#   'url': 'https://truthsocial.com/@FelonPresident',
#   'posts_count': 5,
#   'average_stance': -0.8,
#   'label': '113874359485581537'},
#  '110120596234386134': {'username': 'It_Is_Justified',
#   'display_name': 'I’m Your Daddy',
#   'url': 'https://truthsocial.com/@It_Is_Justified',
#   'posts_count': 3,
#   'average_stance': 0.0,
#   'label': '110120596234386134'},
#  '110816523944252073': {'username': 'Mcnose61',
#   'display_name': 'Mcnose61',
#   'url': 'https://truthsocial.com/@Mcnose61',
#   'posts_count': 1,
#   'average_stance': 1.0,
#   'label': '110816523944252073'},
#  '108326259068870205': {'username': 'Jaybird5977',
#   'display_name': 'Jaybird5977',
#   'url': 'https://truthsocial.com/@Jaybird5977',
#   'posts_count': 1,
#   'average_stance': 0.0,
#   'label': '108326259068870205'},
#  '109157964075653353': {'username': 'AngieO66',
#   'display_name': 'AngieO66',
#   'url': 'https://truthsocial.com/@AngieO66',
#   'posts_count': 1,
#   'average_stance': 0.0,
#   'label': '109157964075653353'},
#  '109017491214179152': {'username': 'Kakie2',
#   'display_name': 'Kakie2',
#   'url': 'https://truthsocial.com/@Kakie2',
#   'posts_count': 3,
#   'average_stance': 0.6666666666666666,
#   'label': '109017491214179152'},
#  '109311354442471721': {'username': 'glenster85',
#   'display_name': 'Glenn Atkinson Sr.',
#   'url': 'https://truthsocial.com/@glenster85',
#   'posts_count': 5,
#   'average_stance': 0.4,
#   'label': '109311354442471721'},
#  '108908691616432040': {'username': 'Beauceant',
#   'display_name': 'Beauceant',
#   'url': 'https://truthsocial.com/@Beauceant',
#   'posts_count': 26,
#   'average_stance': 0.15384615384615385,
#   'label': '108908691616432040'},
#  '113769012520381151': {'username': 'Lucimon',
#   'display_name': '',
#   'url': 'https://truthsocial.com/@Lucimon',
#   'posts_count': 1,
#   'average_stance': 1.0,
#   'label': '113769012520381151'},
#  '110050058970652512': {'username': 'Fishnchips19',
#   'display_name': 'Fishnchips19',
#   'url': 'https://truthsocial.com/@Fishnchips19',
#   'posts_count': 1,
#   'average_stance': 0.0,
#   'label': '110050058970652512'},
#  '107844430972724172': {'username': 'LAugustine',
#   'display_name': '🦅Lisa Augustine🇺🇸',
#   'url': 'https://truthsocial.com/@LAugustine',
#   'posts_count': 1,
#   'average_stance': 1.0,
#   'label': '107844430972724172'},
#  '107865719258155434': {'username': 'dust52moor',
#   'display_name': 'Nous Servons',
#   'url': 'https://truthsocial.com/@dust52moor',
#   'posts_count': 3,
#   'average_stance': 0.0,
#   'label': '107865719258155434'},
#  '108336348169254153': {'username': 'KatieMaeMcG9',
#   'display_name': 'KatieMaeMcG9 ❤️',
#   'url': 'https://truthsocial.com/@KatieMaeMcG9',
#   'posts_count': 2,
#   'average_stance': 0.5,
#   'label': '108336348169254153'},
#  '113954416073065416': {'username': 'Day1Disappointment',
#   'display_name': 'Day 1 Disappointment',
#   'url': 'https://truthsocial.com/@Day1Disappointment',
#   'posts_count': 4,
#   'average_stance': 0.5,
#   'label': '113954416073065416'},
#  '113199294558719735': {'username': 'Nevervotingforhim',
#   'display_name': 'Nevervotingforhim',
#   'url': 'https://truthsocial.com/@Nevervotingforhim',
#   'posts_count': 2,
#   'average_stance': -1.0,
#   'label': '113199294558719735'},
#  '108884406901239156': {'username': 'littlet99',
#   'display_name': 'Eddie James',
#   'url': 'https://truthsocial.com/@littlet99',
#   'posts_count': 12,
#   'average_stance': -0.08333333333333333,
#   'label': '108884406901239156'},
#  '107849406416359250': {'username': 'sainslee',
#   'display_name': '@SI',
#   'url': 'https://truthsocial.com/@sainslee',
#   'posts_count': 11,
#   'average_stance': -0.45454545454545453,
#   'label': '107849406416359250'},
#  '109773806222961246': {'username': 'Dande555',
#   'display_name': 'Dande',
#   'url': 'https://truthsocial.com/@Dande555',
#   'posts_count': 3,
#   'average_stance': 0.0,
#   'label': '109773806222961246'},
#  '108323561284255115': {'username': 'falconsight',
#   'display_name': 'Falcon Sight',
#   'url': 'https://truthsocial.com/@falconsight',
#   'posts_count': 1,
#   'average_stance': 0.0,
#   'label': '108323561284255115'},
#  '112480554355258630': {'username': 'Nokidding4Sure',
#   'display_name': 'Truth4Sure',
#   'url': 'https://truthsocial.com/@Nokidding4Sure',
#   'posts_count': 3,
#   'average_stance': 1.0,
#   'label': '112480554355258630'},
#  '113835363247898734': {'username': 'caravelle',
#   'display_name': 'caravelle',
#   'url': 'https://truthsocial.com/@caravelle',
#   'posts_count': 7,
#   'average_stance': -0.14285714285714285,
#   'label': '113835363247898734'},
#  '111824702112588623': {'username': 'ContinentalAirForcePilot_1776',
#   'display_name': '30573Pinocchios',
#   'url': 'https://truthsocial.com/@ContinentalAirForcePilot_1776',
#   'posts_count': 3,
#   'average_stance': -0.3333333333333333,
#   'label': '111824702112588623'},
#  '108806850881849695': {'username': 'Sc0urge',
#   'display_name': 'Sc0urge',
#   'url': 'https://truthsocial.com/@Sc0urge',
#   'posts_count': 1,
#   'average_stance': -1.0,
#   'label': '108806850881849695'},
#  '107872782783554397': {'username': 'ShoutOutLoud',
#   'display_name': 'KimK',
#   'url': 'https://truthsocial.com/@ShoutOutLoud',
#   'posts_count': 2,
#   'average_stance': 0.5,
#   'label': '107872782783554397'},
#  '111988140692509310': {'username': 'PJBrown621',
#   'display_name': 'PJ🇺🇸',
#   'url': 'https://truthsocial.com/@PJBrown621',
#   'posts_count': 4,
#   'average_stance': 0.0,
#   'label': '111988140692509310'},
#  '114219734909625968': {'username': 'henriquedossantos',
#   'display_name': 'Henrique',
#   'url': 'https://truthsocial.com/@henriquedossantos',
#   'posts_count': 2,
#   'average_stance': 0.0,
#   'label': '114219734909625968'},
#  '107840161655356235': {'username': 'nitroman23',
#   'display_name': 'Francis McLaughlin III',
#   'url': 'https://truthsocial.com/@nitroman23',
#   'posts_count': 2,
#   'average_stance': 0.0,
#   'label': '107840161655356235'},
#  '107834279476814375': {'username': 'AirborneRanger1776',
#   'display_name': 'Colonel Vern',
#   'url': 'https://truthsocial.com/@AirborneRanger1776',
#   'posts_count': 14,
#   'average_stance': -0.07142857142857142,
#   'label': '107834279476814375'},
#  '108706338373133374': {'username': 'IceAge2100',
#   'display_name': 'IceAge2100',
#   'url': 'https://truthsocial.com/@IceAge2100',
#   'posts_count': 3,
#   'average_stance': -0.3333333333333333,
#   'label': '108706338373133374'},
#  '108396892812195404': {'username': 'Whojr',
#   'display_name': 'whojr1963',
#   'url': 'https://truthsocial.com/@Whojr',
#   'posts_count': 2,
#   'average_stance': -0.5,
#   'label': '108396892812195404'},
#  '108207095636103612': {'username': 'The_Nut',
#   'display_name': 'G',
#   'url': 'https://truthsocial.com/@The_Nut',
#   'posts_count': 3,
#   'average_stance': 0.3333333333333333,
#   'label': '108207095636103612'},
#  '108666460644998086': {'username': 'randomrid3ts',
#   'display_name': 'randomrid3ts',
#   'url': 'https://truthsocial.com/@randomrid3ts',
#   'posts_count': 1,
#   'average_stance': 0.0,
#   'label': '108666460644998086'},
#  '107845270606194521': {'username': 'Johnboy2019',
#   'display_name': 'John Farmer',
#   'url': 'https://truthsocial.com/@Johnboy2019',
#   'posts_count': 1,
#   'average_stance': -1.0,
#   'label': '107845270606194521'},
#  '107838157128585454': {'username': 'japeto',
#   'display_name': 'japeto',
#   'url': 'https://truthsocial.com/@japeto',
#   'posts_count': 9,
#   'average_stance': -0.2222222222222222,
#   'label': '107838157128585454'},
#  '110255955256373077': {'username': 'yeuxmarrons77',
#   'display_name': 'yeuxmarrons77',
#   'url': 'https://truthsocial.com/@yeuxmarrons77',
#   'posts_count': 2,
#   'average_stance': 0.0,
#   'label': '110255955256373077'},
#  '113354500051075875': {'username': 'angrycreamsicle1313',
#   'display_name': 'Mitch',
#   'url': 'https://truthsocial.com/@angrycreamsicle1313',
#   'posts_count': 1,
#   'average_stance': 0.0,
#   'label': '113354500051075875'},
#  '108688349598347328': {'username': 'scottie56',
#   'display_name': '',
#   'url': 'https://truthsocial.com/@scottie56',
#   'posts_count': 1,
#   'average_stance': -1.0,
#   'label': '108688349598347328'},
#  '113195206420828526': {'username': 'Night1979',
#   'display_name': 'Night1979',
#   'url': 'https://truthsocial.com/@Night1979',
#   'posts_count': 28,
#   'average_stance': -0.25,
#   'label': '113195206420828526'},
#  '113009208104688527': {'username': 'haydenac1994',
#   'display_name': 'Amba',
#   'url': 'https://truthsocial.com/@haydenac1994',
#   'posts_count': 10,
#   'average_stance': 0.2,
#   'label': '113009208104688527'},
#  '107842282007478386': {'username': 'BestE',
#   'display_name': 'NursElisa 🇺🇸🇮🇹👩🏻\u200d⚕️⭐️🧩',
#   'url': 'https://truthsocial.com/@BestE',
#   'posts_count': 1,
#   'average_stance': -1.0,
#   'label': '107842282007478386'},
#  '108811769452979934': {'username': 'joniwag',
#   'display_name': 'Joni',
#   'url': 'https://truthsocial.com/@joniwag',
#   'posts_count': 3,
#   'average_stance': 0.0,
#   'label': '108811769452979934'},
#  '111336562010541190': {'username': 'TrumpSucksWind',
#   'display_name': 'Doogey',
#   'url': 'https://truthsocial.com/@TrumpSucksWind',
#   'posts_count': 23,
#   'average_stance': -0.30434782608695654,
#   'label': '111336562010541190'},
#  '110219465858209247': {'username': 'michVoter',
#   'display_name': 'michVoter',
#   'url': 'https://truthsocial.com/@michVoter',
#   'posts_count': 3,
#   'average_stance': -0.3333333333333333,
#   'label': '110219465858209247'},
#  '109116889301631683': {'username': 'Victoria61',
#   'display_name': 'Victoria61',
#   'url': 'https://truthsocial.com/@Victoria61',
#   'posts_count': 10,
#   'average_stance': 0.0,
#   'label': '109116889301631683'},
#  '112293966988832162': {'username': '1_truebeliever',
#   'display_name': '',
#   'url': 'https://truthsocial.com/@1_truebeliever',
#   'posts_count': 5,
#   'average_stance': -0.2,
#   'label': '112293966988832162'},
#  '108523339892903520': {'username': 'Yankeebuff34',
#   'display_name': 'Andrew',
#   'url': 'https://truthsocial.com/@Yankeebuff34',
#   'posts_count': 3,
#   'average_stance': 0.3333333333333333,
#   'label': '108523339892903520'},
#  '107839244240978670': {'username': 'lyel',
#   'display_name': 'Lyel',
#   'url': 'https://truthsocial.com/@lyel',
#   'posts_count': 1,
#   'average_stance': 0.0,
#   'label': '107839244240978670'},
#  '107835587662432528': {'username': 'csturms',
#   'display_name': 'CherBear',
#   'url': 'https://truthsocial.com/@csturms',
#   'posts_count': 6,
#   'average_stance': 0.0,
#   'label': '107835587662432528'},
#  '109675247805006880': {'username': 'TheUtopist',
#   'display_name': 'Patrick',
#   'url': 'https://truthsocial.com/@TheUtopist',
#   'posts_count': 9,
#   'average_stance': -0.3333333333333333,
#   'label': '109675247805006880'},
#  '110578765977081410': {'username': 'seedafuture',
#   'display_name': 'MAGA Joe',
#   'url': 'https://truthsocial.com/@seedafuture',
#   'posts_count': 2,
#   'average_stance': -0.5,
#   'label': '110578765977081410'},
#  '114282574498535838': {'username': 'yachtyachtyacht',
#   'display_name': '',
#   'url': 'https://truthsocial.com/@yachtyachtyacht',
#   'posts_count': 1,
#   'average_stance': 0.0,
#   'label': '114282574498535838'},
#  '107838519000069926': {'username': 'PoppyPilz',
#   'display_name': 'Mr Pilz',
#   'url': 'https://truthsocial.com/@PoppyPilz',
#   'posts_count': 29,
#   'average_stance': 0.13793103448275862,
#   'label': '107838519000069926'},
#  '113872175588407086': {'username': 'LeftChicago1',
#   'display_name': '',
#   'url': 'https://truthsocial.com/@LeftChicago1',
#   'posts_count': 3,
#   'average_stance': -0.3333333333333333,
#   'label': '113872175588407086'},
#  '107837385766698747': {'username': 'Vet4Life',
#   'display_name': 'Cecil Massey',
#   'url': 'https://truthsocial.com/@Vet4Life',
#   'posts_count': 2,
#   'average_stance': 0.0,
#   'label': '107837385766698747'},
#  '112892189424415905': {'username': 'CecilJohnson1',
#   'display_name': 'Cecil Johnson',
#   'url': 'https://truthsocial.com/@CecilJohnson1',
#   'posts_count': 2,
#   'average_stance': 0.0,
#   'label': '112892189424415905'},
#  '107841009039326159': {'username': 'smr0323',
#   'display_name': 'smr san diego',
#   'url': 'https://truthsocial.com/@smr0323',
#   'posts_count': 1,
#   'average_stance': -1.0,
#   'label': '107841009039326159'},
#  '107835861434046122': {'username': 'shannonarmenis',
#   'display_name': 'Shannon Armenis',
#   'url': 'https://truthsocial.com/@shannonarmenis',
#   'posts_count': 2,
#   'average_stance': 0.5,
#   'label': '107835861434046122'},
#  '108806240068787367': {'username': 'aussie21',
#   'display_name': 'Austin J. Proffitt',
#   'url': 'https://truthsocial.com/@aussie21',
#   'posts_count': 3,
#   'average_stance': 0.0,
#   'label': '108806240068787367'},
#  '107850063402107663': {'username': 'lady1221',
#   'display_name': 'Seaking Truth',
#   'url': 'https://truthsocial.com/@lady1221',
#   'posts_count': 3,
#   'average_stance': 0.0,
#   'label': '107850063402107663'},
#  '114282715464254748': {'username': 'asswhipy',
#   'display_name': 'asswhipy',
#   'url': 'https://truthsocial.com/@asswhipy',
#   'posts_count': 1,
#   'average_stance': 0.0,
#   'label': '114282715464254748'},
#  '109532684435959669': {'username': 'pldrryan',
#   'display_name': 'pldrryan',
#   'url': 'https://truthsocial.com/@pldrryan',
#   'posts_count': 2,
#   'average_stance': 0.5,
#   'label': '109532684435959669'},
#  '112790036596564519': {'username': 'mike6253',
#   'display_name': 'USA',
#   'url': 'https://truthsocial.com/@mike6253',
#   'posts_count': 14,
#   'average_stance': -0.21428571428571427,
#   'label': '112790036596564519'},
#  '108216608603370077': {'username': 'kimkat22',
#   'display_name': 'blueskies',
#   'url': 'https://truthsocial.com/@kimkat22',
#   'posts_count': 3,
#   'average_stance': 0.0,
#   'label': '108216608603370077'},
#  '110514183987624264': {'username': 'Speddly1',
#   'display_name': 'speddly1',
#   'url': 'https://truthsocial.com/@Speddly1',
#   'posts_count': 1,
#   'average_stance': 1.0,
#   'label': '110514183987624264'},
#  '112532703078676804': {'username': 'Adnil1962',
#   'display_name': '',
#   'url': 'https://truthsocial.com/@Adnil1962',
#   'posts_count': 3,
#   'average_stance': -0.3333333333333333,
#   'label': '112532703078676804'},
#  '113896618569397762': {'username': 'TheAustrianTruth',
#   'display_name': 'TheAustrianTruth',
#   'url': 'https://truthsocial.com/@TheAustrianTruth',
#   'posts_count': 2,
#   'average_stance': -0.5,
#   'label': '113896618569397762'},
#  '108966365039072888': {'username': '19Lyds',
#   'display_name': '19Lyds',
#   'url': 'https://truthsocial.com/@19Lyds',
#   'posts_count': 4,
#   'average_stance': 0.75,
#   'label': '108966365039072888'},
#  '107865082650468512': {'username': 'PBrooks77',
#   'display_name': 'PBrooks',
#   'url': 'https://truthsocial.com/@PBrooks77',
#   'posts_count': 3,
#   'average_stance': -0.3333333333333333,
#   'label': '107865082650468512'},
#  '107924525069854590': {'username': 'Rob1Dallas',
#   'display_name': 'Texan4Life',
#   'url': 'https://truthsocial.com/@Rob1Dallas',
#   'posts_count': 2,
#   'average_stance': 0.0,
#   'label': '107924525069854590'},
#  '107839467438433186': {'username': 'cnnrules',
#   'display_name': 'CubbyBlue',
#   'url': 'https://truthsocial.com/@cnnrules',
#   'posts_count': 3,
#   'average_stance': -1.0,
#   'label': '107839467438433186'},
#  '108322866696399868': {'username': 'Mah84',
#   'display_name': 'FDT2025',
#   'url': 'https://truthsocial.com/@Mah84',
#   'posts_count': 1,
#   'average_stance': 0.0,
#   'label': '108322866696399868'},
#  '108912917942203758': {'username': 'mcat944',
#   'display_name': '',
#   'url': 'https://truthsocial.com/@mcat944',
#   'posts_count': 12,
#   'average_stance': -0.3333333333333333,
#   'label': '108912917942203758'},
#  '108478106109424484': {'username': 'blackberry110',
#   'display_name': 'blackberry',
#   'url': 'https://truthsocial.com/@blackberry110',
#   'posts_count': 13,
#   'average_stance': -0.3076923076923077,
#   'label': '108478106109424484'},
#  '111225859816805915': {'username': 'Jman81788',
#   'display_name': 'Josh S',
#   'url': 'https://truthsocial.com/@Jman81788',
#   'posts_count': 3,
#   'average_stance': 0.0,
#   'label': '111225859816805915'},
#  '110074391013358073': {'username': 'Pucker1952',
#   'display_name': 'Ethel Fudpucker',
#   'url': 'https://truthsocial.com/@Pucker1952',
#   'posts_count': 2,
#   'average_stance': 0.0,
#   'label': '110074391013358073'},
#  '113436749804343476': {'username': 'Sansa1234',
#   'display_name': 'Sansa',
#   'url': 'https://truthsocial.com/@Sansa1234',
#   'posts_count': 8,
#   'average_stance': -0.625,
#   'label': '113436749804343476'},
#  '112338910460772878': {'username': 'ssnyder3535',
#   'display_name': 'Truthseeker',
#   'url': 'https://truthsocial.com/@ssnyder3535',
#   'posts_count': 2,
#   'average_stance': 0.0,
#   'label': '112338910460772878'},
#  '107979220625084286': {'username': 'JBINTHEHIZZY',
#   'display_name': 'Justice for All',
#   'url': 'https://truthsocial.com/@JBINTHEHIZZY',
#   'posts_count': 12,
#   'average_stance': -0.4166666666666667,
#   'label': '107979220625084286'},
#  '108338550355822193': {'username': 'JayA90',
#   'display_name': 'JayA90',
#   'url': 'https://truthsocial.com/@JayA90',
#   'posts_count': 4,
#   'average_stance': -0.5,
#   'label': '108338550355822193'},
#  '113239782592580951': {'username': 'TheseColorsDontBleed',
#   'display_name': 'TheseColorsDontBleed',
#   'url': 'https://truthsocial.com/@TheseColorsDontBleed',
#   'posts_count': 3,
#   'average_stance': -0.3333333333333333,
#   'label': '113239782592580951'},
#  '108252241775176742': {'username': 'deplorablegee',
#   'display_name': 'Gina Cassetta',
#   'url': 'https://truthsocial.com/@deplorablegee',
#   'posts_count': 22,
#   'average_stance': 0.045454545454545456,
#   'label': '108252241775176742'},
#  '112168198236306538': {'username': 'notakaren8689',
#   'display_name': '.',
#   'url': 'https://truthsocial.com/@notakaren8689',
#   'posts_count': 13,
#   'average_stance': 0.07692307692307693,
#   'label': '112168198236306538'},
#  '107843586224911929': {'username': 'grumpster12',
#   'display_name': 'Joe Black',
#   'url': 'https://truthsocial.com/@grumpster12',
#   'posts_count': 6,
#   'average_stance': -0.16666666666666666,
#   'label': '107843586224911929'},
#  '113104422091276937': {'username': 'Smalliecatcher',
#   'display_name': '',
#   'url': 'https://truthsocial.com/@Smalliecatcher',
#   'posts_count': 5,
#   'average_stance': -0.4,
#   'label': '113104422091276937'},
#  '109371160070334185': {'username': 'MikeyB101',
#   'display_name': 'MikeyB101',
#   'url': 'https://truthsocial.com/@MikeyB101',
#   'posts_count': 4,
#   'average_stance': 0.0,
#   'label': '109371160070334185'},
#  '110555645318448659': {'username': 'TheTruthForOnce',
#   'display_name': 'TheTruthForOnce',
#   'url': 'https://truthsocial.com/@TheTruthForOnce',
#   'posts_count': 2,
#   'average_stance': 0.0,
#   'label': '110555645318448659'},
#  '111248065367883046': {'username': 'Blue4You2',
#   'display_name': 'Blue4You2',
#   'url': 'https://truthsocial.com/@Blue4You2',
#   'posts_count': 1,
#   'average_stance': -1.0,
#   'label': '111248065367883046'},
#  '107839123582742380': {'username': 'ljc4Liberty',
#   'display_name': 'LJ',
#   'url': 'https://truthsocial.com/@ljc4Liberty',
#   'posts_count': 3,
#   'average_stance': 0.0,
#   'label': '107839123582742380'},
#  '111808732488057050': {'username': 'stinkfeet',
#   'display_name': 'highly exaggerated',
#   'url': 'https://truthsocial.com/@stinkfeet',
#   'posts_count': 3,
#   'average_stance': -1.0,
#   'label': '111808732488057050'},
#  '107952408787015145': {'username': 'twoedgesword',
#   'display_name': 'twoedgesword',
#   'url': 'https://truthsocial.com/@twoedgesword',
#   'posts_count': 1,
#   'average_stance': 0.0,
#   'label': '107952408787015145'},
#  '107848385840300241': {'username': 'SwtPeas23',
#   'display_name': 'Swt-Pea',
#   'url': 'https://truthsocial.com/@SwtPeas23',
#   'posts_count': 5,
#   'average_stance': 0.4,
#   'label': '107848385840300241'},
#  '109118694636381346': {'username': 'Payray970',
#   'display_name': 'Payray970',
#   'url': 'https://truthsocial.com/@Payray970',
#   'posts_count': 1,
#   'average_stance': 0.0,
#   'label': '109118694636381346'},
#  '108048110896552247': {'username': 'Knott_Chu',
#   'display_name': 'Ι ས τ ཇ ι',
#   'url': 'https://truthsocial.com/@Knott_Chu',
#   'posts_count': 3,
#   'average_stance': 0.0,
#   'label': '108048110896552247'},
#  '111563384266636067': {'username': 'banksrjason',
#   'display_name': '',
#   'url': 'https://truthsocial.com/@banksrjason',
#   'posts_count': 2,
#   'average_stance': -0.5,
#   'label': '111563384266636067'},
#  '107849187907096600': {'username': 'AlfredENeuman2',
#   'display_name': 'Alfred E. Newman',
#   'url': 'https://truthsocial.com/@AlfredENeuman2',
#   'posts_count': 7,
#   'average_stance': -0.2857142857142857,
#   'label': '107849187907096600'},
#  '114222275053152360': {'username': 'RealMia',
#   'display_name': 'Speaking my Mind',
#   'url': 'https://truthsocial.com/@RealMia',
#   'posts_count': 4,
#   'average_stance': 0.5,
#   'label': '114222275053152360'},
#  '107844188360773053': {'username': 'dlpiccia',
#   'display_name': 'dlpiccia',
#   'url': 'https://truthsocial.com/@dlpiccia',
#   'posts_count': 1,
#   'average_stance': 1.0,
#   'label': '107844188360773053'},
#  '110848521857206792': {'username': 'lonegreywolf',
#   'display_name': 'lonegreywolf',
#   'url': 'https://truthsocial.com/@lonegreywolf',
#   'posts_count': 12,
#   'average_stance': -0.25,
#   'label': '110848521857206792'},
#  '112735009968374278': {'username': 'cbrown4728',
#   'display_name': 'cbrown4728',
#   'url': 'https://truthsocial.com/@cbrown4728',
#   'posts_count': 1,
#   'average_stance': 1.0,
#   'label': '112735009968374278'},
#  '113699197379080753': {'username': 'marzship365',
#   'display_name': 'Matt4Marz',
#   'url': 'https://truthsocial.com/@marzship365',
#   'posts_count': 11,
#   'average_stance': 0.09090909090909091,
#   'label': '113699197379080753'},
#  '107843621835163678': {'username': 'MyOwnMind',
#   'display_name': 'MyOwnMind',
#   'url': 'https://truthsocial.com/@MyOwnMind',
#   'posts_count': 4,
#   'average_stance': 0.75,
#   'label': '107843621835163678'},
#  '109118300353423863': {'username': 'Moosemaximus',
#   'display_name': 'Moose maximus',
#   'url': 'https://truthsocial.com/@Moosemaximus',
#   'posts_count': 45,
#   'average_stance': 0.022222222222222223,
#   'label': '109118300353423863'},
#  '114245943824885493': {'username': 'fatspraytanfraud',
#   'display_name': '',
#   'url': 'https://truthsocial.com/@fatspraytanfraud',
#   'posts_count': 8,
#   'average_stance': -0.375,
#   'label': '114245943824885493'},
#  '112054231783143682': {'username': 'Jwefe6',
#   'display_name': 'Jwefe6',
#   'url': 'https://truthsocial.com/@Jwefe6',
#   'posts_count': 1,
#   'average_stance': 1.0,
#   'label': '112054231783143682'},
#  '108333957442953695': {'username': 'AnotherMarko',
#   'display_name': 'AnotherMarko',
#   'url': 'https://truthsocial.com/@AnotherMarko',
#   'posts_count': 13,
#   'average_stance': 0.5384615384615384,
#   'label': '108333957442953695'},
#  '110221944525929266': {'username': 'dustystevens',
#   'display_name': 'Dusty Stevens',
#   'url': 'https://truthsocial.com/@dustystevens',
#   'posts_count': 1,
#   'average_stance': 0.0,
#   'label': '110221944525929266'},
#  '114157612400886646': {'username': '_KenAdams',
#   'display_name': '_KenAdams',
#   'url': 'https://truthsocial.com/@_KenAdams',
#   'posts_count': 36,
#   'average_stance': -0.2222222222222222,
#   'label': '114157612400886646'},
#  '108643411502057140': {'username': 'Dow20Jones',
#   'display_name': 'Mr Big Shots',
#   'url': 'https://truthsocial.com/@Dow20Jones',
#   'posts_count': 5,
#   'average_stance': -0.4,
#   'label': '108643411502057140'},
#  '112140323281312222': {'username': 'davdk111',
#   'display_name': 'DK',
#   'url': 'https://truthsocial.com/@davdk111',
#   'posts_count': 1,
#   'average_stance': 0.0,
#   'label': '112140323281312222'},
#  '107834394761512710': {'username': 'islandpatriot',
#   'display_name': 'MAGAT',
#   'url': 'https://truthsocial.com/@islandpatriot',
#   'posts_count': 2,
#   'average_stance': -0.5,
#   'label': '107834394761512710'},
#  '110894441216503721': {'username': 'MarinaSapir',
#   'display_name': '',
#   'url': 'https://truthsocial.com/@MarinaSapir',
#   'posts_count': 2,
#   'average_stance': 0.0,
#   'label': '110894441216503721'},
#  '112164124255611707': {'username': 'concreteguy10',
#   'display_name': '',
#   'url': 'https://truthsocial.com/@concreteguy10',
#   'posts_count': 1,
#   'average_stance': 1.0,
#   'label': '112164124255611707'},
#  '107834550044052630': {'username': 'BluSoul',
#   'display_name': 'BluSoul',
#   'url': 'https://truthsocial.com/@BluSoul',
#   'posts_count': 1,
#   'average_stance': 0.0,
#   'label': '107834550044052630'},
#  '110771329219187838': {'username': 'GMChief',
#   'display_name': 'GMChief',
#   'url': 'https://truthsocial.com/@GMChief',
#   'posts_count': 2,
#   'average_stance': 0.5,
#   'label': '110771329219187838'},
#  '114286469315740639': {'username': 'blackout95',
#   'display_name': 'blackout95',
#   'url': 'https://truthsocial.com/@blackout95',
#   'posts_count': 3,
#   'average_stance': -0.3333333333333333,
#   'label': '114286469315740639'},
#  '108534317208593459': {'username': 'truthorlie69',
#   'display_name': '',
#   'url': 'https://truthsocial.com/@truthorlie69',
#   'posts_count': 1,
#   'average_stance': -1.0,
#   'label': '108534317208593459'},
#  '113610308275185505': {'username': 'Trevero69',
#   'display_name': 'Trever',
#   'url': 'https://truthsocial.com/@Trevero69',
#   'posts_count': 2,
#   'average_stance': 1.0,
#   'label': '113610308275185505'},
#  '112781911674853273': {'username': 'tammy_roton',
#   'display_name': 'Christ Follower & Retired  NP',
#   'url': 'https://truthsocial.com/@tammy_roton',
#   'posts_count': 1,
#   'average_stance': 0.0,
#   'label': '112781911674853273'},
#  '108229369097599490': {'username': 'SonOHughes57',
#   'display_name': 'Huggins J Phiri',
#   'url': 'https://truthsocial.com/@SonOHughes57',
#   'posts_count': 1,
#   'average_stance': 0.0,
#   'label': '108229369097599490'},
#  '113479315066064038': {'username': 'Wedaphillips',
#   'display_name': 'Wedaphillips',
#   'url': 'https://truthsocial.com/@Wedaphillips',
#   'posts_count': 3,
#   'average_stance': 0.6666666666666666,
#   'label': '113479315066064038'},
#  '110050374446769336': {'username': 'tdillard01',
#   'display_name': '',
#   'url': 'https://truthsocial.com/@tdillard01',
#   'posts_count': 2,
#   'average_stance': 0.0,
#   'label': '110050374446769336'},
#  '107850798088215969': {'username': 'nonuthin',
#   'display_name': 'nonuthin',
#   'url': 'https://truthsocial.com/@nonuthin',
#   'posts_count': 1,
#   'average_stance': 0.0,
#   'label': '107850798088215969'},
#  '107815422836159436': {'username': 'Schmaboolie',
#   'display_name': 'Extreme Ultra Maga Murph Dude🩸',
#   'url': 'https://truthsocial.com/@Schmaboolie',
#   'posts_count': 3,
#   'average_stance': 0.0,
#   'label': '107815422836159436'},
#  '112157468451218310': {'username': 'River57',
#   'display_name': 'River57',
#   'url': 'https://truthsocial.com/@River57',
#   'posts_count': 1,
#   'average_stance': 1.0,
#   'label': '112157468451218310'},
#  '107844170565207532': {'username': 'stuntmeup',
#   'display_name': '2024TrumpAgain',
#   'url': 'https://truthsocial.com/@stuntmeup',
#   'posts_count': 7,
#   'average_stance': 0.42857142857142855,
#   'label': '107844170565207532'},
#  '113737065852699449': {'username': 'FirstLadyTrump',
#   'display_name': 'First Lady Donnie',
#   'url': 'https://truthsocial.com/@FirstLadyTrump',
#   'posts_count': 26,
#   'average_stance': -0.038461538461538464,
#   'label': '113737065852699449'},
#  '107845283617253674': {'username': 'standingwarrior',
#   'display_name': 'Standing Warrior',
#   'url': 'https://truthsocial.com/@standingwarrior',
#   'posts_count': 1,
#   'average_stance': 0.0,
#   'label': '107845283617253674'},
#  '110951037283868154': {'username': 'thethruth1',
#   'display_name': 'KERNEL.',
#   'url': 'https://truthsocial.com/@thethruth1',
#   'posts_count': 2,
#   'average_stance': 1.0,
#   'label': '110951037283868154'},
#  '110516757711779110': {'username': 'Imindictable',
#   'display_name': '',
#   'url': 'https://truthsocial.com/@Imindictable',
#   'posts_count': 8,
#   'average_stance': -0.875,
#   'label': '110516757711779110'},
#  '113910154445028094': {'username': 'PatriotGal2025',
#   'display_name': 'PatriotGal2025',
#   'url': 'https://truthsocial.com/@PatriotGal2025',
#   'posts_count': 2,
#   'average_stance': 0.0,
#   'label': '113910154445028094'},
#  '113366081179321246': {'username': 'majorkleen',
#   'display_name': '',
#   'url': 'https://truthsocial.com/@majorkleen',
#   'posts_count': 2,
#   'average_stance': 1.0,
#   'label': '113366081179321246'},
#  '107920274653484672': {'username': 'Sprinterms',
#   'display_name': 'sprinterms',
#   'url': 'https://truthsocial.com/@Sprinterms',
#   'posts_count': 2,
#   'average_stance': -0.5,
#   'label': '107920274653484672'},
#  '112164368802122780': {'username': 'QueTrumpCountryUSA',
#   'display_name': 'QueTrumpCountryUSA',
#   'url': 'https://truthsocial.com/@QueTrumpCountryUSA',
#   'posts_count': 1,
#   'average_stance': 1.0,
#   'label': '112164368802122780'},
#  '108763123813576563': {'username': 'cokomo123',
#   'display_name': 'cokomo123',
#   'url': 'https://truthsocial.com/@cokomo123',
#   'posts_count': 1,
#   'average_stance': 0.0,
#   'label': '108763123813576563'},
#  '107843220074347692': {'username': 'JamesArm',
#   'display_name': 'JamesArm',
#   'url': 'https://truthsocial.com/@JamesArm',
#   'posts_count': 1,
#   'average_stance': 1.0,
#   'label': '107843220074347692'},
#  '108751180893999033': {'username': 'Airforceman12',
#   'display_name': 'Airforceman12',
#   'url': 'https://truthsocial.com/@Airforceman12',
#   'posts_count': 1,
#   'average_stance': 0.0,
#   'label': '108751180893999033'},
#  '109201021428174305': {'username': 'NESSsweet',
#   'display_name': 'NESSsweet',
#   'url': 'https://truthsocial.com/@NESSsweet',
#   'posts_count': 1,
#   'average_stance': 0.0,
#   'label': '109201021428174305'},
#  '108339520322175298': {'username': 'B4reehl',
#   'display_name': 'B4reehl',
#   'url': 'https://truthsocial.com/@B4reehl',
#   'posts_count': 3,
#   'average_stance': 0.0,
#   'label': '108339520322175298'},
#  '108379658061424717': {'username': 'mani177',
#   'display_name': 'mani177',
#   'url': 'https://truthsocial.com/@mani177',
#   'posts_count': 15,
#   'average_stance': 0.6,
#   'label': '108379658061424717'},
#  '107917851082130893': {'username': 'papi4',
#   'display_name': '',
#   'url': 'https://truthsocial.com/@papi4',
#   'posts_count': 1,
#   'average_stance': 0.0,
#   'label': '107917851082130893'},
#  '107838145998585316': {'username': 'PaPatriot17762021',
#   'display_name': 'Pa Patriot 17762021',
#   'url': 'https://truthsocial.com/@PaPatriot17762021',
#   'posts_count': 6,
#   'average_stance': 0.3333333333333333,
#   'label': '107838145998585316'},
#  '107859579512301777': {'username': 'jmaq',
#   'display_name': 'Jim McFadden',
#   'url': 'https://truthsocial.com/@jmaq',
#   'posts_count': 1,
#   'average_stance': 0.0,
#   'label': '107859579512301777'},
#  '108280806747544768': {'username': 'pianoplayer7',
#   'display_name': 'piano girl',
#   'url': 'https://truthsocial.com/@pianoplayer7',
#   'posts_count': 21,
#   'average_stance': 0.6190476190476191,
#   'label': '108280806747544768'},
#  '107867361323611471': {'username': 'tazbot',
#   'display_name': 'Jamari',
#   'url': 'https://truthsocial.com/@tazbot',
#   'posts_count': 2,
#   'average_stance': 0.0,
#   'label': '107867361323611471'},
#  '107838890090282315': {'username': 'KKWalker',
#   'display_name': 'kkwalker',
#   'url': 'https://truthsocial.com/@KKWalker',
#   'posts_count': 3,
#   'average_stance': 0.3333333333333333,
#   'label': '107838890090282315'},
#  '107859526030763887': {'username': 'zaharias',
#   'display_name': 'Zaharias',
#   'url': 'https://truthsocial.com/@zaharias',
#   'posts_count': 5,
#   'average_stance': -0.4,
#   'label': '107859526030763887'},
#  '108341435684763777': {'username': 'Bavery1776',
#   'display_name': 'Troath Sential',
#   'url': 'https://truthsocial.com/@Bavery1776',
#   'posts_count': 7,
#   'average_stance': -0.2857142857142857,
#   'label': '108341435684763777'},
#  '107837262691809572': {'username': 'Ruth22',
#   'display_name': 'Ruth',
#   'url': 'https://truthsocial.com/@Ruth22',
#   'posts_count': 1,
#   'average_stance': -1.0,
#   'label': '107837262691809572'},
#  '111964477714094862': {'username': 'Magajoethechristain',
#   'display_name': 'JustcallmeJoe',
#   'url': 'https://truthsocial.com/@Magajoethechristain',
#   'posts_count': 16,
#   'average_stance': 0.0,
#   'label': '111964477714094862'},
#  '108207092245147727': {'username': 'Dust_Parts',
#   'display_name': 'R.G.',
#   'url': 'https://truthsocial.com/@Dust_Parts',
#   'posts_count': 1,
#   'average_stance': -1.0,
#   'label': '108207092245147727'},
#  '108308142672333082': {'username': 'dwillisfl',
#   'display_name': 'D Willis',
#   'url': 'https://truthsocial.com/@dwillisfl',
#   'posts_count': 3,
#   'average_stance': 0.0,
#   'label': '108308142672333082'},
#  '108806275290478849': {'username': 'JackieWoo',
#   'display_name': 'Jackie',
#   'url': 'https://truthsocial.com/@JackieWoo',
#   'posts_count': 1,
#   'average_stance': 1.0,
#   'label': '108806275290478849'},
#  '107839299001267757': {'username': 'JadeSez',
#   'display_name': 'Jade Jayne',
#   'url': 'https://truthsocial.com/@JadeSez',
#   'posts_count': 7,
#   'average_stance': 0.14285714285714285,
#   'label': '107839299001267757'},
#  '108229502182328763': {'username': 'livingJesus',
#   'display_name': 'LJ',
#   'url': 'https://truthsocial.com/@livingJesus',
#   'posts_count': 1,
#   'average_stance': 0.0,
#   'label': '108229502182328763'},
#  '114010419802990580': {'username': 'tbrown2575',
#   'display_name': 'Tbrown',
#   'url': 'https://truthsocial.com/@tbrown2575',
#   'posts_count': 2,
#   'average_stance': 0.5,
#   'label': '114010419802990580'},
#  '107844578490642699': {'username': 'kipem',
#   'display_name': 'kipem',
#   'url': 'https://truthsocial.com/@kipem',
#   'posts_count': 5,
#   'average_stance': 0.6,
#   'label': '107844578490642699'},
#  '108323591884299573': {'username': 'Toolmaker51',
#   'display_name': 'Toolmaker51',
#   'url': 'https://truthsocial.com/@Toolmaker51',
#   'posts_count': 2,
#   'average_stance': 1.0,
#   'label': '108323591884299573'},
#  '112018373775761960': {'username': 'Lindakriney',
#   'display_name': 'LK',
#   'url': 'https://truthsocial.com/@Lindakriney',
#   'posts_count': 2,
#   'average_stance': 0.0,
#   'label': '112018373775761960'},
#  '112781993084903714': {'username': 'shiningcityonhill',
#   'display_name': '',
#   'url': 'https://truthsocial.com/@shiningcityonhill',
#   'posts_count': 2,
#   'average_stance': 1.0,
#   'label': '112781993084903714'},
#  '113908011819205023': {'username': 'TruthMatters_2025',
#   'display_name': 'TruthMatters_2025',
#   'url': 'https://truthsocial.com/@TruthMatters_2025',
#   'posts_count': 1,
#   'average_stance': 1.0,
#   'label': '113908011819205023'},
#  '107843896297376099': {'username': 'careukent',
#   'display_name': 'Careu',
#   'url': 'https://truthsocial.com/@careukent',
#   'posts_count': 1,
#   'average_stance': 1.0,
#   'label': '107843896297376099'},
#  '113931754791967615': {'username': 'GalenR',
#   'display_name': 'ForceOne',
#   'url': 'https://truthsocial.com/@GalenR',
#   'posts_count': 3,
#   'average_stance': -0.3333333333333333,
#   'label': '113931754791967615'},
#  '112139736159553978': {'username': 'larrydoublel',
#   'display_name': 'doublel',
#   'url': 'https://truthsocial.com/@larrydoublel',
#   'posts_count': 1,
#   'average_stance': 0.0,
#   'label': '112139736159553978'},
#  '107842398723821084': {'username': 'BasiaGrace',
#   'display_name': 'BasiaGrace🌹',
#   'url': 'https://truthsocial.com/@BasiaGrace',
#   'posts_count': 1,
#   'average_stance': 0.0,
#   'label': '107842398723821084'},
#  '107911078775799927': {'username': 'HJLynn',
#   'display_name': 'Lynn McBride',
#   'url': 'https://truthsocial.com/@HJLynn',
#   'posts_count': 1,
#   'average_stance': 0.0,
#   'label': '107911078775799927'},
#  '113926564430962382': {'username': 'Neutralityuncle',
#   'display_name': 'Neutralityuncle',
#   'url': 'https://truthsocial.com/@Neutralityuncle',
#   'posts_count': 8,
#   'average_stance': 0.875,
#   'label': '113926564430962382'},
#  '107839521877241497': {'username': 'Lwomble',
#   'display_name': 'Lil Texas Panhandler',
#   'url': 'https://truthsocial.com/@Lwomble',
#   'posts_count': 1,
#   'average_stance': 0.0,
#   'label': '107839521877241497'},
#  '114300421659151329': {'username': 'cmg1990',
#   'display_name': 'Carlos G',
#   'url': 'https://truthsocial.com/@cmg1990',
#   'posts_count': 2,
#   'average_stance': 0.0,
#   'label': '114300421659151329'},
#  '113041138711478250': {'username': 'JayBandersnatch',
#   'display_name': '',
#   'url': 'https://truthsocial.com/@JayBandersnatch',
#   'posts_count': 2,
#   'average_stance': 0.0,
#   'label': '113041138711478250'},
#  '112025457373179992': {'username': 'mkauffman1',
#   'display_name': 'mkauffman',
#   'url': 'https://truthsocial.com/@mkauffman1',
#   'posts_count': 1,
#   'average_stance': 0.0,
#   'label': '112025457373179992'},
#  '107838732189418153': {'username': 'DavidLMusic',
#   'display_name': 'David L. Martin 🎧',
#   'url': 'https://truthsocial.com/@DavidLMusic',
#   'posts_count': 2,
#   'average_stance': 0.5,
#   'label': '107838732189418153'},
#  '113188066674320273': {'username': 'Calleegirl1',
#   'display_name': 'constance',
#   'url': 'https://truthsocial.com/@Calleegirl1',
#   'posts_count': 1,
#   'average_stance': 1.0,
#   'label': '113188066674320273'},
#  '109117212445837503': {'username': 'kellysferret1_',
#   'display_name': 'kellysferret',
#   'url': 'https://truthsocial.com/@kellysferret1_',
#   'posts_count': 1,
#   'average_stance': 1.0,
#   'label': '109117212445837503'}}

# %%
partition_bluesky = community_louvain.best_partition(
    Bluesky_G.to_undirected(),
    resolution=1.0
)

community_ids_bluesky = set(partition_bluesky.values())

communities_bluesky = {
    community_id: {
        node: Bluesky_G.nodes(data=True)[node] for node, comm in partition_bluesky.items()
        if comm == community_id
    }
    for community_id in community_ids_bluesky
}

communities_bluesky = {
    community_id: nodes
    for community_id, nodes in communities_bluesky.items()
    if len(nodes) > 50
}

communities_bluesky_sizes = {
    community_id: len(nodes)
    for community_id, nodes in communities_bluesky.items()
}

print(f"Communities: {len(communities_bluesky)}")

communities_leanings_bluesky = {
    community_id: np.average(
        a=[n['average_stance'] for _, n in nodes.items()],
        weights=[n['posts_count'] for _, n in nodes.items()]
    )
    for community_id, nodes in communities_bluesky.items()
}

print_communities_stance_histogram(
    communities_bluesky_sizes,
    communities_leanings_bluesky
)
# Out:
# Communities: 61

# %%
# Information Diffusion Simulation (SIR)
# Susceptible-Infected-Recovered Model

def simulate_sir(
        graph: nx.DiGraph,
        start_node: str,
        beta: float = 0.05, # Approximation for 0.10 * <k>^-1
        gamma: float = 0.2,
) -> list[str]:
    """
    Simulates the SIR model on a directed graph.

    Parameters:
        graph (nx.DiGraph): The directed graph.
        beta (float): Infection probability per neighbor per time step.
        gamma (float): Recovery probability per infected node per time step.
        start_node (str): The starting node's ID.

    Returns:
        list of str: The list of nodes that are in the 'recovered' state at the end of the simulation
    """
    states = {node: 'S' for node in graph.nodes}
    states[start_node] = 'I'

    while True:
        new_states = states.copy()
        # Infect neighbors
        for node in graph.nodes:
            if states[node] == 'I':
                for neighbor in graph.successors(node):
                    if states[neighbor] == 'S' and random.random() < beta:
                        new_states[neighbor] = 'I' # An Infected node has a beta-chance of infecting a Susceptible neighbour

                # Recover
                if random.random() < gamma:
                    new_states[node] = 'R' # An Infected node has a gamma-chance of Recovering

        # Stop if no infection remains
        if all(state != 'I' for state in new_states.values()):
            break

        states = new_states

    return [node for node in graph.nodes if states[node] == 'R']

def average_stance(G, l) -> float:
    return float(np.average([
        G.nodes(data=True)[node]['average_stance']
        for node in l
    ]))

# %%
num_bins = 10
bin_edges = np.linspace(-1, 1, num_bins + 1)
bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2

binned_data = defaultdict(list)
recovered_count_per_bin = defaultdict(int)

for i, (node, attr) in enumerate(Truth_G.nodes(data=True)):
    node_stance = attr['average_stance']
    bin_index = np.digitize(node_stance, bin_edges) - 1
    if 0 <= bin_index < num_bins:
        recovered = simulate_sir(Truth_G, node)
        if recovered:
            stance = average_stance(Truth_G, recovered)
            binned_data[bin_index].append(stance)
            recovered_count_per_bin[bin_index] += len(recovered)

    if i % 1000 == 0:
        print(f"{i}/{len(Truth_G.nodes)}")

# Prepare boxplot data
boxplot_data = [binned_data[i] for i in range(num_bins)]
counts = [recovered_count_per_bin[i] for i in range(num_bins)]

# Normalize counts for coloring
norm = colors.Normalize(vmin=min(counts), vmax=max(counts))
cmap = cm.get_cmap('plasma')

# Create figure and axes explicitly
fig, ax = plt.subplots(figsize=(12, 6))

# Plot boxplot
box = ax.boxplot(boxplot_data, positions=bin_centers, widths=0.15, patch_artist=True)

# Color each box based on count
for patch, count in zip(box['boxes'], counts):
    patch.set_facecolor(cmap(norm(count)))

# Add colorbar linked to this axes
sm = cm.ScalarMappable(cmap=cmap, norm=norm)
sm.set_array([])  # Only needed to make colorbar work
fig.colorbar(sm, ax=ax, label="# of Measures in Bin")

# Labeling
ax.set_xlabel("Initial Node's Average Stance (binned)")
ax.set_ylabel("Recovered Nodes' Average Stance")
ax.set_title("SIR Spread - Truth")
ax.set_xticks(bin_centers)
ax.set_xticklabels([f"{x:.2f}" for x in bin_centers])
ax.grid(True, linestyle='--', alpha=0.6)

plt.tight_layout()
plt.show()
# Out:
# 0/14748
# 1000/14748
# 2000/14748
# 3000/14748
# 4000/14748
# 5000/14748
# 6000/14748
# 7000/14748
# 8000/14748
# 9000/14748
# 10000/14748
# 11000/14748
# 12000/14748
# 13000/14748
# 14000/14748
# C:\Users\Filippo Corti\AppData\Local\Temp\ipykernel_16264\1864350099.py:27: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap('plasma')

# %%
num_bins = 10
bin_edges = np.linspace(-1, 1, num_bins + 1)
bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2

binned_data = defaultdict(list)
recovered_count_per_bin = defaultdict(int)

for i, (node, attr) in enumerate(Bluesky_G.nodes(data=True)):
    node_stance = attr['average_stance']
    bin_index = np.digitize(node_stance, bin_edges) - 1
    if 0 <= bin_index < num_bins:
        recovered = simulate_sir(Bluesky_G, node)
        if recovered:
            stance = average_stance(Bluesky_G, recovered)
            binned_data[bin_index].append(stance)
            recovered_count_per_bin[bin_index] += len(recovered)

    if i % 1000 == 0:
        print(f"{i}/{len(Bluesky_G.nodes)}")

# Prepare boxplot data
boxplot_data = [binned_data[i] for i in range(num_bins)]
counts = [recovered_count_per_bin[i] for i in range(num_bins)]

# Normalize counts for coloring
norm = colors.Normalize(vmin=min(counts), vmax=max(counts))
cmap = cm.get_cmap('plasma')

# Create figure and axes explicitly
fig, ax = plt.subplots(figsize=(12, 6))

# Plot boxplot
box = ax.boxplot(boxplot_data, positions=bin_centers, widths=0.15, patch_artist=True)

# Color each box based on count
for patch, count in zip(box['boxes'], counts):
    patch.set_facecolor(cmap(norm(count)))

# Add colorbar linked to this axes
sm = cm.ScalarMappable(cmap=cmap, norm=norm)
sm.set_array([])  # Only needed to make colorbar work
fig.colorbar(sm, ax=ax, label="# of Measures in Bin")

# Labeling
ax.set_xlabel("Initial Node's Average Stance (binned)")
ax.set_ylabel("Recovered Nodes' Average Stance")
ax.set_title("SIR Spread - Bluesky")
ax.set_xticks(bin_centers)
ax.set_xticklabels([f"{x:.2f}" for x in bin_centers])
ax.grid(True, linestyle='--', alpha=0.6)

plt.tight_layout()
plt.show()
# Out:
# 0/14748
# 1000/14748
# 2000/14748
# 3000/14748
# 4000/14748
# 5000/14748
# 6000/14748
# 7000/14748
# 8000/14748
# 9000/14748
# 10000/14748
# 11000/14748
# 12000/14748
# 13000/14748
# 14000/14748
# C:\Users\Filippo Corti\AppData\Local\Temp\ipykernel_16264\3544110791.py:27: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap('plasma')
