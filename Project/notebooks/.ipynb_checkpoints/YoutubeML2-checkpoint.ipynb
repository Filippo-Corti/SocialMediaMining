# %%
import multiprocessing

import pandas as pd
import numpy as np
import itertools
import importlib
import missingno as msno
import matplotlib.pyplot as plt
import warnings
import imblearn
import spacy
import re
from joblib import dump, load
from collections import Counter



from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.metrics import f1_score, roc_auc_score, precision_score
from sklearn.model_selection import learning_curve, validation_curve, train_test_split, KFold, StratifiedKFold, \
    cross_val_score, GridSearchCV, RandomizedSearchCV, cross_validate, RepeatedStratifiedKFold
from sklearn.linear_model import Perceptron, LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.decomposition import PCA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
from sklearn.impute import SimpleImputer, KNNImputer
from sklearn.preprocessing import FunctionTransformer, StandardScaler, OneHotEncoder, OrdinalEncoder
from sklearn.datasets import fetch_openml
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import make_scorer
from sklearn.metrics import recall_score, roc_curve, auc, precision_recall_curve, classification_report

from sklearn.decomposition import TruncatedSVD

from scipy.stats import loguniform, beta, uniform

from mlxtend.feature_selection import SequentialFeatureSelector as SFS

from imblearn.over_sampling import SMOTE, RandomOverSampler
from imblearn.pipeline import Pipeline as IMBPipeline
from imblearn.combine import SMOTETomek
from imblearn.over_sampling import ADASYN
from imblearn.under_sampling import RandomUnderSampler
from sklearn.svm import SVC

from Project.utils.analysis.ml_utils import StanceCrossPredictor
from Project.utils.storage import youtube_db as db
from Project.utils.analysis import ml_utils as ml
from Project.utils.analysis import text_classifier as tc

importlib.reload(db)
importlib.reload(ml)
importlib.reload(tc)

trump_podcasts = [
    "xrFdHO7FH8w",
    "blqIZGXWUpU",
    "s11uIW7wi-E",
    "vC5cHjcgt5g",
    "G80iLTctFuY",
    "qCbfTN-caFI",
    "Ry1IjOft95c",
    "S7BTdUaNQM8",
    "1SsmPh8gCxU",
    "-dmwG54QsKc",
    "nwQil7tcImI",
    "G9lXnwuZ2qs",
    "hBMoPUAeLnY"
]

harris_podcasts = [
    "_KCRsjPCiCI",
    "bzThwqnQJDY",
    "7L4sts7I3xI",
    "pNbwMrBMGgE",
    "Vu5yD3fu6A8",
]

youtube_db = db.SQLiteYoutubeSaver(db_name='../db/youtube.db')

# %% [markdown]
# ### 1. Load the Dataset

# %%
youtube_db.cursor.execute(f"""
SELECT video_id, content, gemini_label, sentiment, emotion, bias, leaning, is_political
FROM CommentAnalysis JOIN Comments on Comments.id = CommentAnalysis.id
WHERE gemini_label IS NOT NULL
""")

data = youtube_db.cursor.fetchall()

df = pd.DataFrame(data)
df.columns = ['video_id', 'content', 'label', 'sentiment', 'emotion', 'bias', 'leaning', 'is_political']
df['podcast_guest'] = ['Trump' if video_id in trump_podcasts else 'Harris' for video_id in df['video_id']]
df['rep_label'] = [1 if l == 'Republican' else 0 for l in df['label']]
df['dem_label'] = [1 if l == 'Democratic' else 0 for l in df['label']]
df.drop('video_id', axis=1, inplace=True)

df
# Out:
#                                                  content       label  \
# 0                           Best Podcast of All-time? 🤔🔥  Republican
# 1                                Definitely my favorite!  Republican
# 2                                         No, best guest  Republican
# 3                                               Probably     Neutral
# 4                                       Under 30 seconds     Neutral
# ...                                                  ...         ...
# 18973  @@leroyjetson2329Folks with Caribbean heritage...     Neutral
# 18974            I am only here for the comment section.     Neutral
# 18975                😅😂 this comment section is trouble!     Neutral
# 18976  @@HI-DEF100 I’ve been looking for a positive c...  Republican
# 18977  @@Waydo2306 ive just been spamming “Trump 2024...  Republican
#
#       sentiment       emotion   bias leaning  is_political podcast_guest  \
# 0      Positive           joy  RIGHT   RIGHT             0         Trump
# 1      Positive           joy  RIGHT    LEFT             0         Trump
# 2      Positive           joy  RIGHT   RIGHT             0         Trump
# 3       Neutral  anticipation  RIGHT    LEFT             0         Trump
# 4       Neutral  anticipation  RIGHT   RIGHT             0         Trump
# ...         ...           ...    ...     ...           ...           ...
# 18973  Negative  anticipation   LEFT   RIGHT             1        Harris
# 18974   Neutral         anger  RIGHT   RIGHT             0        Harris
# 18975  Negative         anger  RIGHT    LEFT             0        Harris
# 18976   Neutral       sadness   LEFT    LEFT             0        Harris
# 18977  Negative         anger  RIGHT   RIGHT             1        Harris
#
#        rep_label  dem_label
# 0              1          0
# 1              1          0
# 2              1          0
# 3              0          0
# 4              0          0
# ...          ...        ...
# 18973          0          0
# 18974          0          0
# 18975          0          0
# 18976          1          0
# 18977          1          0
#
# [18978 rows x 10 columns]

# %%
X = df[['content', 'podcast_guest', 'sentiment', 'emotion', 'bias', 'leaning', 'is_political']]

y_rep = df['rep_label']
y_dem = df['dem_label']

# %% [markdown]
# # A. Republican Classifier

# %% [markdown]
# ### 2. Split the Dataset

# %%
X_train_rep, X_test_rep, y_train_rep, y_test_rep = train_test_split(
    X, y_rep, test_size=0.2, stratify=y_rep, random_state=42, shuffle=True
)

# %% [markdown]
# ### 3. Preprocessing

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ('spacy_vect', ml.SpacyVectorTransformer(), ['content']),
        ('guest_ohe', OneHotEncoder(drop='first', handle_unknown='ignore'), ['podcast_guest', 'sentiment', 'emotion', 'bias', 'leaning']),
    ]
)

X_train_rep_processed = preprocessor.fit_transform(X_train_rep) # Fit and Transform on Train Set

# %%
X_test_rep_processed = preprocessor.transform(X_test_rep) # Only Transform on Test Set
# Out:
# C:\Users\Filippo Corti\miniconda3\envs\SocialMediaMining\Lib\site-packages\sklearn\preprocessing\_encoders.py:246: UserWarning: Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %% [markdown]
# ### 4. Pipeline

# %%
pipeline = IMBPipeline([
    # Preprocessing is moved outside for computational purposes
    ('sampler', None),
    ('dim_reduction', None),
    ('classifier', LogisticRegression())
])

scoring = {
    'f1': make_scorer(f1_score, zero_division=0),
    'precision': make_scorer(precision_score, zero_division=0),
    'recall': make_scorer(recall_score, zero_division=0),
    'roc_auc': make_scorer(roc_auc_score)
}

# %% [markdown]
# ### 5. Find Best Model with CV

# %%
all_configs = ml.get_configurations_grid_for_precision()

print(f"Total pipeline combinations: {len(all_configs)}")

custom_scorer = make_scorer(ml.precision_recall_weighted, greater_is_better=True)

rs_rep = RandomizedSearchCV(
    pipeline,
    param_distributions=all_configs,
    n_iter=25,
    n_jobs=5,
    cv=StratifiedKFold(n_splits=3, shuffle=True, random_state=42),
    scoring=custom_scorer,
    error_score='raise',
    refit=True,
    random_state=42,
    verbose=3,
    return_train_score=True
)

rs_rep.fit(X_train_rep_processed, y_train_rep)
# Out:
# Total pipeline combinations: 8
# Fitting 3 folds for each of 25 candidates, totalling 75 fits
# Pipeline(steps=[('sampler', SMOTE(random_state=42, sampling_strategy=0.6)),
#                 ('dim_reduction', None),
#                 ('classifier',
#                  RandomForestClassifier(class_weight={0: 1.5, 1: 1},
#                                         max_depth=12, max_features=0.5,
#                                         min_samples_leaf=30,
#                                         min_samples_split=60, n_estimators=50,
#                                         random_state=42))])

# %%
best_model = rs_rep.best_estimator_

best_model
# Out:
# Pipeline(steps=[('sampler', SMOTE(random_state=42, sampling_strategy=0.6)),
#                 ('dim_reduction', None),
#                 ('classifier',
#                  RandomForestClassifier(class_weight={0: 1.5, 1: 1},
#                                         max_depth=12, max_features=0.5,
#                                         min_samples_leaf=30,
#                                         min_samples_split=60, n_estimators=50,
#                                         random_state=42))])

# %%
# Results

print("TRAINING SET:")
print(classification_report(y_train_rep, best_model.predict(X_train_rep_processed)))

print("TEST SET:")
print(classification_report(y_test_rep, best_model.predict(X_test_rep_processed)))
# Out:
# TRAINING SET:
#               precision    recall  f1-score   support
#
#            0       0.80      0.96      0.88     10359
#            1       0.86      0.50      0.63      4823
#
#     accuracy                           0.81     15182
#    macro avg       0.83      0.73      0.75     15182
# weighted avg       0.82      0.81      0.80     15182
#
# TEST SET:
#               precision    recall  f1-score   support
#
#            0       0.76      0.93      0.84      2590
#            1       0.71      0.38      0.49      1206
#
#     accuracy                           0.75      3796
#    macro avg       0.74      0.65      0.67      3796
# weighted avg       0.75      0.75      0.73      3796

# %% [markdown]
# ### 6. Find Threshold value for Precision-Recall balance

# %%
y_proba = rs_rep.predict_proba(X_test_rep_processed)[:, 1]
precision, recall, thresholds = precision_recall_curve(y_test_rep, y_proba)

# Plot to see your options
plt.figure(figsize=(10, 6))
plt.plot(recall, precision)
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')

for target_precision in [0.5, 0.55, 0.6, 0.65, 0.7, 0.8]:
    if np.any(precision >= target_precision):
        idx = np.argmax(precision >= target_precision)
        print(f"{idx}: Precision {target_precision:.2f} → Recall {recall[idx]:.3f} → Threshold {thresholds[idx]:.3f}")
# Out:
# 1792: Precision 0.50 → Recall 0.757 → Threshold 0.262
# 2087: Precision 0.55 → Recall 0.698 → Threshold 0.304
# 2384: Precision 0.60 → Recall 0.614 → Threshold 0.354
# 2629: Precision 0.65 → Recall 0.532 → Threshold 0.409
# 2883: Precision 0.70 → Recall 0.425 → Threshold 0.474
# 3460: Precision 0.80 → Recall 0.101 → Threshold 0.681

# %%
best_threshold = 0.344 # Pick manually

y_test_tuned = (y_proba >= best_threshold).astype(int)

print("TEST SET (with Best Threshold):")
print(classification_report(y_test_rep, y_test_tuned))
# Out:
# TEST SET (with Best Threshold):
#               precision    recall  f1-score   support
#
#            0       0.82      0.80      0.81      2590
#            1       0.59      0.63      0.61      1206
#
#     accuracy                           0.74      3796
#    macro avg       0.71      0.71      0.71      3796
# weighted avg       0.75      0.74      0.75      3796

# %% [markdown]
# ### 7. Save the Results

# %%
final_model = ml.ClassifierWithThresholdModel(
    pipeline=best_model,
    preprocessor=preprocessor,
    threshold=best_threshold,
)

ml.ClassifierWithThresholdModel.save_model(final_model, '../data/best_model_rep.joblib')
# Out:
# Model exported to ../data/best_model_rep.joblib

# %% [markdown]
# # B. Democratic Classifier

# %% [markdown]
# ### 2. Split the Dataset

# %%
X_train_dem, X_test_dem, y_train_dem, y_test_dem = train_test_split(
    X, y_dem, test_size=0.2, stratify=y_dem, random_state=42, shuffle=True
)

# %% [markdown]
# ### 3. Preprocessing

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ('spacy_vect', ml.SpacyVectorTransformer(), ['content']),
        ('guest_ohe', OneHotEncoder(drop='first', handle_unknown='ignore'), ['podcast_guest', 'sentiment', 'emotion', 'bias', 'leaning']),
    ]
)

X_train_dem_processed = preprocessor.fit_transform(X_train_dem) # Fit and Transform on Train Set

# %%
X_test_dem_processed = preprocessor.transform(X_test_dem) # Only Transform on Test Set

# %% [markdown]
# ### 4. Pipeline

# %%
pipeline = IMBPipeline([
    # Preprocessing is moved outside for computational purposes
    ('sampler', None),
    ('dim_reduction', None),
    ('classifier', LogisticRegression())
])

scoring = {
    'f1': make_scorer(f1_score, zero_division=0),
    'precision': make_scorer(precision_score, zero_division=0),
    'recall': make_scorer(recall_score, zero_division=0),
    'roc_auc': make_scorer(roc_auc_score)
}

# %% [markdown]
# ### 5. Find Best Model with CV

# %%
all_configs = ml.get_configurations_grid_for_precision()

print(f"Total pipeline combinations: {len(all_configs)}")

custom_scorer = make_scorer(ml.precision_recall_weighted, greater_is_better=True)

rs_dem = RandomizedSearchCV(
    pipeline,
    param_distributions=all_configs,
    n_iter=20,
    n_jobs=5,
    cv=StratifiedKFold(n_splits=3, shuffle=True, random_state=42),
    scoring=custom_scorer,
    error_score='raise',
    refit=True,
    random_state=42,
    verbose=3,
    return_train_score=True
)

rs_dem.fit(X_train_dem_processed, y_train_dem)

best_model = rs_dem.best_estimator_

best_model
# Out:
# Total pipeline combinations: 4
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# Pipeline(steps=[('sampler', None),
#                 ('dim_reduction', PCA(n_components=0.9, random_state=42)),
#                 ('classifier',
#                  RandomForestClassifier(class_weight={0: 2, 1: 1}, max_depth=12,
#                                         max_features=0.5, min_samples_leaf=30,
#                                         min_samples_split=40,
#                                         random_state=42))])

# %%
# Results

print("TRAINING SET:")
print(classification_report(y_train_dem, best_model.predict(X_train_dem_processed)))

print("TEST SET:")
print(classification_report(y_test_dem, best_model.predict(X_test_dem_processed)))
# Out:
# TRAINING SET:
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.93     13196
#            1       0.98      0.06      0.11      1986
#
#     accuracy                           0.88     15182
#    macro avg       0.93      0.53      0.52     15182
# weighted avg       0.89      0.88      0.83     15182
#
# TEST SET:
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93      3299
#            1       0.67      0.02      0.04       497
#
#     accuracy                           0.87      3796
#    macro avg       0.77      0.51      0.48      3796
# weighted avg       0.84      0.87      0.81      3796

# %% [markdown]
# ### 6. Find Threshold value for Precision-Recall balance

# %%
y_proba = rs_dem.predict_proba(X_test_dem_processed)[:, 1]
precision, recall, thresholds = precision_recall_curve(y_test_dem, y_proba)

# Plot to see your options
plt.figure(figsize=(10, 6))
plt.plot(recall, precision)
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')

for target_precision in [0.4, 0.45, 0.5, 0.55, 0.6, 0.65, 0.7, 0.8]:
    if np.any(precision >= target_precision):
        idx = np.argmax(precision >= target_precision)
        print(f"{idx}: Precision {target_precision:.2f} → Recall {recall[idx]:.3f} → Threshold {thresholds[idx]:.3f}")
# Out:
# 2926: Precision 0.40 → Recall 0.565 → Threshold 0.129
# 3080: Precision 0.45 → Recall 0.497 → Threshold 0.159
# 3214: Precision 0.50 → Recall 0.416 → Threshold 0.189
# 3321: Precision 0.55 → Recall 0.340 → Threshold 0.222
# 3415: Precision 0.60 → Recall 0.258 → Threshold 0.270
# 3505: Precision 0.65 → Recall 0.161 → Threshold 0.321
# 3528: Precision 0.70 → Recall 0.141 → Threshold 0.338
# 3619: Precision 0.80 → Recall 0.012 → Threshold 0.540

# %%
best_threshold = 0.222 # Pick manually

y_test_tuned = (y_proba >= best_threshold).astype(int)

print("TEST SET (with Best Threshold):")
print(classification_report(y_test_dem, y_test_tuned))
# Out:
# TEST SET (with Best Threshold):
#               precision    recall  f1-score   support
#
#            0       0.91      0.96      0.93      3299
#            1       0.55      0.34      0.42       497
#
#     accuracy                           0.88      3796
#    macro avg       0.73      0.65      0.67      3796
# weighted avg       0.86      0.88      0.86      3796

# %% [markdown]
# ### 7. Save the Results

# %%
final_model = ml.ClassifierWithThresholdModel(
    pipeline=best_model,
    preprocessor=preprocessor,
    threshold=best_threshold,
)

ml.ClassifierWithThresholdModel.save_model(final_model, '../data/best_model_dem.joblib')
# Out:
# Model exported to ../data/best_model_dem.joblib

# %% [markdown]
# # C. Merge the 2 Models

# %%
# Load the entire dataset

youtube_db.cursor.execute(f"""
SELECT Comments.id, video_id, content, gemini_label, sentiment, emotion, bias, leaning, is_political
FROM CommentAnalysis JOIN Comments on Comments.id = CommentAnalysis.id
""")

data = youtube_db.cursor.fetchall()

df = pd.DataFrame(data)
df.columns = ['id', 'video_id', 'content', 'label', 'sentiment', 'emotion', 'bias', 'leaning', 'is_political']
df['label'] = [{'Neutral': 0, 'Republican': 1, 'Democratic': 2}.get(l) for l in df['label']]
df['podcast_guest'] = ['Trump' if video_id in trump_podcasts else 'Harris' for video_id in df['video_id']]
df.drop('video_id', axis=1, inplace=True)

df
# Out:
#                                                        id  \
# 0                              UgyfluKW3Ug3sy7JipJ4AaABAg
# 1       UgyfluKW3Ug3sy7JipJ4AaABAg.A4dWYlIOxqSA4dWgAZknY6
# 2       UgyfluKW3Ug3sy7JipJ4AaABAg.A4dWYlIOxqSA4dWpEh0att
# 3       UgyfluKW3Ug3sy7JipJ4AaABAg.A4dWYlIOxqSA4dWpMKmUEI
# 4       UgyfluKW3Ug3sy7JipJ4AaABAg.A4dWYlIOxqSA4dWt4CmVAq
# ...                                                   ...
# 114695  UgyHorsmGTU9LHUXCBJ4AaABAg.AA9n_pk7NK3AA9xuMlvsYZ
# 114696  UgyHorsmGTU9LHUXCBJ4AaABAg.AA9n_pk7NK3AA9yMqEcrPM
# 114697  UgyHorsmGTU9LHUXCBJ4AaABAg.AA9n_pk7NK3AAA-zsorgCI
# 114698  UgyHorsmGTU9LHUXCBJ4AaABAg.AA9n_pk7NK3AAA04ke2mdj
# 114699  UgyHorsmGTU9LHUXCBJ4AaABAg.AA9n_pk7NK3AAA79Ta87lf
#
#                                                   content  label sentiment  \
# 0                            Best Podcast of All-time? 🤔🔥    1.0  Positive
# 1                                 Definitely my favorite!    1.0  Positive
# 2                                          No, best guest    1.0  Positive
# 3                                                Probably    0.0   Neutral
# 4                                        Under 30 seconds    0.0   Neutral
# ...                                                   ...    ...       ...
# 114695  How do you check the numbers from  your phone ...    NaN  Negative
# 114696  @@BruceDragon-sf1tr just google it fam. I prom...    NaN   Neutral
# 114697                       its now 34k to 88k now lolol    NaN  Positive
# 114698  @@BruceDragon-sf1trjust add it to your browser...    NaN   Neutral
# 114699  Views: 764496, Likes: 35116, Dislikes: 93843 a...    NaN   Neutral
#
#              emotion   bias leaning  is_political podcast_guest
# 0                joy  RIGHT   RIGHT             0         Trump
# 1                joy  RIGHT    LEFT             0         Trump
# 2                joy  RIGHT   RIGHT             0         Trump
# 3       anticipation  RIGHT    LEFT             0         Trump
# 4       anticipation  RIGHT   RIGHT             0         Trump
# ...              ...    ...     ...           ...           ...
# 114695       disgust  RIGHT   RIGHT             0        Harris
# 114696      optimism   LEFT   RIGHT             0        Harris
# 114697           joy   LEFT    LEFT             0        Harris
# 114698         anger   LEFT   RIGHT             0        Harris
# 114699           joy   LEFT   RIGHT             0        Harris
#
# [114700 rows x 9 columns]

# %%
new_X = df[['id', 'content', 'podcast_guest', 'sentiment', 'emotion', 'bias', 'leaning', 'is_political']]

rep_model = ml.ClassifierWithThresholdModel.load_model('../data/best_model_rep.joblib')

dem_model = ml.ClassifierWithThresholdModel.load_model('../data/best_model_dem.joblib')
# Out:
# Loaded model with threshold 0.344
# Loaded model with threshold 0.222

# %%
final_predictor = ml.StanceCrossPredictor(
    republican_model=rep_model,
    democratic_model=dem_model,
)

# %%
# Checkout predictions on the subset that has a label
# Disclaimer: it's the data the models have been trained on

df_with_labels = df[df['label'].notna()]

df_with_labels
# Out:
#                                                        id  \
# 0                              UgyfluKW3Ug3sy7JipJ4AaABAg
# 1       UgyfluKW3Ug3sy7JipJ4AaABAg.A4dWYlIOxqSA4dWgAZknY6
# 2       UgyfluKW3Ug3sy7JipJ4AaABAg.A4dWYlIOxqSA4dWpEh0att
# 3       UgyfluKW3Ug3sy7JipJ4AaABAg.A4dWYlIOxqSA4dWpMKmUEI
# 4       UgyfluKW3Ug3sy7JipJ4AaABAg.A4dWYlIOxqSA4dWt4CmVAq
# ...                                                   ...
# 114649  UgwCaYjmWTVjWtNcl9V4AaABAg.AA7cVVMTlASAA8hHsViVmY
# 114671  UgyR6ug3JqspPes1zsR4AaABAg.AA9UwQXdpEiAA9_4M4OOI-
# 114684  UgyR6ug3JqspPes1zsR4AaABAg.AA9UwQXdpEiAA9wSDvAdjX
# 114689  UgyHorsmGTU9LHUXCBJ4AaABAg.AA9n_pk7NK3AA9tHqzb_hg
# 114690  UgyHorsmGTU9LHUXCBJ4AaABAg.AA9n_pk7NK3AA9tiYvTcNi
#
#                                                   content  label sentiment  \
# 0                            Best Podcast of All-time? 🤔🔥    1.0  Positive
# 1                                 Definitely my favorite!    1.0  Positive
# 2                                          No, best guest    1.0  Positive
# 3                                                Probably    0.0   Neutral
# 4                                        Under 30 seconds    0.0   Neutral
# ...                                                   ...    ...       ...
# 114649  @@leroyjetson2329Folks with Caribbean heritage...    0.0  Negative
# 114671            I am only here for the comment section.    0.0   Neutral
# 114684                😅😂 this comment section is trouble!    0.0  Negative
# 114689  @@HI-DEF100 I’ve been looking for a positive c...    1.0   Neutral
# 114690  @@Waydo2306 ive just been spamming “Trump 2024...    1.0  Negative
#
#              emotion   bias leaning  is_political podcast_guest
# 0                joy  RIGHT   RIGHT             0         Trump
# 1                joy  RIGHT    LEFT             0         Trump
# 2                joy  RIGHT   RIGHT             0         Trump
# 3       anticipation  RIGHT    LEFT             0         Trump
# 4       anticipation  RIGHT   RIGHT             0         Trump
# ...              ...    ...     ...           ...           ...
# 114649  anticipation   LEFT   RIGHT             1        Harris
# 114671         anger  RIGHT   RIGHT             0        Harris
# 114684         anger  RIGHT    LEFT             0        Harris
# 114689       sadness   LEFT    LEFT             0        Harris
# 114690         anger  RIGHT   RIGHT             1        Harris
#
# [18978 rows x 9 columns]

# %%
X_test = df_with_labels[['content', 'podcast_guest', 'sentiment', 'emotion', 'bias', 'leaning', 'is_political']]
y_test = df_with_labels['label']

y_predictions = final_predictor.predict(X_test)

print(classification_report(y_test, y_predictions))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.58      0.77      0.66     10466
#          1.0       0.28      0.23      0.26      6029
#          2.0       0.00      0.00      0.00      2483
#
#     accuracy                           0.50     18978
#    macro avg       0.29      0.34      0.31     18978
# weighted avg       0.41      0.50      0.45     18978
# C:\Users\Filippo Corti\miniconda3\envs\SocialMediaMining\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Filippo Corti\miniconda3\envs\SocialMediaMining\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Filippo Corti\miniconda3\envs\SocialMediaMining\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
Counter(y_predictions)
# Out:
# Counter({0: 13949, 1: 5029})

# %%
predictions = final_predictor.predict(new_X)

Counter(predictions)
# Out:
# Counter({0: 95358, 1: 14039, 2: 5303})

# %%
# Out:
# Counter({0: 91520, 1: 20675, 2: 2505})

# %%
# Save results in the DB

def map_label(x):
    if x == 0: return 0
    if x == 1: return 1
    if x == 2: return -1

predictions = [map_label(x) for x in predictions]

update_data = [(label, id) for id, label in zip(df['id'], predictions)]

# Execute all at once
cursor = youtube_db.cursor
cursor.executemany(
    """
    INSERT INTO CommentAnalysis (id, label)
    VALUES (?, ?)
    ON CONFLICT(id) DO UPDATE SET label = excluded.label
    """,
    update_data
)
youtube_db.conn.commit()
