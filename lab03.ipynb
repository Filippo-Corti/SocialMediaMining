# %%
import networkx as nx

# %%
G = nx.read_edgelist("data/email-EU.edges")

# %%
G.order(), G.size() # Numero di Nodi e di Archi
# Out:
# (32430, 54397)

# %%
# nx.write_graphml(G, path="data/email-EU.graphml")

# %%
# Out:
# AtlasView({'1': {}, '25': {}, '42': {}, '52': {}, '82': {}, '83': {}, '85': {}, '87': {}, '102': {}, '122': {}, '173': {}, '174': {}, '214': {}, '340': {}, '342': {}, '355': {}, '452': {}, '453': {}, '478': {}, '486': {}, '502': {}, '518': {}, '755': {}, '761': {}, '857': {}, '888': {}, '950': {}, '954': {}, '979': {}, '1023': {}, '1171': {}, '1241': {}, '1363': {}, '1433': {}, '1440': {}, '1468': {}, '1514': {}, '1600': {}, '1610': {}, '1830': {}, '2179': {}, '2212': {}, '2319': {}, '2398': {}, '2473': {}, '2664': {}, '3386': {}, '3717': {}, '3818': {}, '3870': {}, '3999': {}, '4079': {}, '4167': {}, '4267': {}, '4376': {}, '4471': {}, '4473': {}, '4481': {}, '4576': {}, '4833': {}, '4940': {}, '5099': {}, '5142': {}, '5325': {}, '5476': {}, '5501': {}, '5649': {}, '5957': {}, '6024': {}, '6298': {}, '6909': {}, '6930': {}, '7703': {}, '7826': {}, '7961': {}, '8167': {}, '8181': {}, '8243': {}, '8537': {}, '8860': {}, '8947': {}, '8995': {}, '9016': {}, '9063': {}, '9364': {}, '9798
# ...
